# %% [markdown]
# ## Text Generation
# ### Introduction
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.
#
# ### Select Text to Imitate
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                        transcript
# Amanda Seales   Now, y’all keep asking me, “Amanda, who is thi...
# Bert Kreischer  [electronic music playing] [male announcer] La...
# Marc Maron      [audience chattering indistinctly] [man] Ladie...
# Pete Davidson   So, Louis C.K. tried to get me fired from SNL ...
# Stewart Lee     This programme contains very strong language a...

# %%
# Extract only Pete Davidson text
ali_text = data.transcript.loc['Pete Davidson']
ali_text[:200]
# Out:
# 'So, Louis C.K. tried to get me fired from SNL my first year, and this is that story. -So, it’s, like, 2014 or ’15, uh, and it’s the finale of SNL, and I-I was so shocked and happy that I didn’t get fi'

# %% [markdown]
# ### Build a Markov Chain Function
# We are going to build a simple Markov chain function that creates a dictionary:
#
# - The keys should be all of the words in the corpus
# - The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
pete_dict = markov_chain(ali_text)
pete_dict
# Out:
# {'So,': ['Louis',
#   'I',
#   'like,',
#   'yeah,',
#   'I',
#   'like',
#   'uh,',
#   'you',
#   'like,',
#   'you',
#   'the',
#   'yeah.',
#   'in',
#   'this',
#   'we’re'],
#  'Louis': ['C.K.',
#   'C.K.',
#   'C.K.',
#   'C.K.',
#   'C.K.',
#   'just',
#   'told',
#   'brought',
#   'C.K.'],
#  'C.K.': ['tried', 'was', 'was,', 'was,', 'stops', 'doesn’t', 'jerks'],
#  'tried': ['to', 'five'],
#  'to': ['get',
#   'relive',
#   'and',
#   'be',
#   'you.',
#   'go',
#   'know',
#   'the',
#   'work',
#   'hear',
#   'talk',
#   'talk',
#   'you',
#   'hype',
#   'feel',
#   'say,',
#   'talk',
#   'you,',
#   'do',
#   'have',
#   'my',
#   'leave',
#   'happen,',
#   'anybody,',
#   'jerk',
#   'me,',
#   'jerk',
#   'do.',
#   'have',
#   'make',
#   'work.',
#   'tell',
#   'make',
#   'make',
#   'hurt',
#   'make',
#   'be',
#   'change',
#   'tell,',
#   'be',
#   'say',
#   'slam',
#   'shove',
#   'the',
#   'learn',
#   'fuck,”',
#   'gain,',
#   'knock.',
#   'you',
#   'you,',
#   'fucking',
#   'slap',
#   'his',
#   'me,',
#   'him,',
#   'come',
#   'a',
#   '2',
#   'jail',
#   'apologize',
#   'do,',
#   'fucking.',
#   'fucking.',
#   'do',
#   'watch.',
#   'happen',
#   'pause',
#   'go',
#   'do',
#   'the',
#   'be',
#   'the',
#   'everybody',
#   'be',
#   'apologize',
#   'be',
#   'be',
#   'say',
#   'happen',
#   'her,',
#   'be',
#   'be',
#   'ruin',
#   'Dunkin’',
#   'you.',
#   'like',
#   'that',
#   'sit',
#   'her.',
#   'you,',
#   'everyone',
#   'the',
#   'enjoy',
#   'explain',
#   'which',
#   'make',
#   'get',
#   'be',
#   'like,',
#   'the',
#   'explain',
#   'you',
#   'life.',
#   'go',
#   'finish',
#   'finish',
#   'be',
#   'guilt',
#   'meet',
#   'do',
#   'tell',
#   'love',
#   'my',
#   'tell',
#   'think,',
#   'the',
#   'try',
#   'go',
#   'fuck',
#   'the',
#   'be',
#   'know',
#   'go'],
#  'get': ['me',
#   'fired,',
#   'to',
#   'a',
#   'a',
#   'an',
#   'some',
#   'it.',
#   'to',
#   'in',
#   'pulled',
#   'in',
#   'in',
#   'shot',
#   'to',
#   'an',
#   'ahead',
#   'a',
#   'it!”',
#   'to',
#   'the',
#   'us',
#   'us',
#   'a',
#   'the',
#   'a'],
#  'me': ['fired',
#   'and',
#   'issue,',
#   'to,',
#   'that,',
#   'to',
#   '’cause',
#   'just',
#   'out,',
#   'a',
#   'very',
#   'either,',
#   'in',
#   'another',
#   'in',
#   'write',
#   'he',
#   'all',
#   'and',
#   'and',
#   'were,',
#   'into',
#   'some',
#   'smile.',
#   '♪\n♪',
#   'But',
#   'heartless',
#   'stories',
#   'he',
#   'and',
#   'and'],
#  'fired': ['from', 'you.'],
#  'from': ['SNL',
#   'Lorne',
#   'his',
#   'this',
#   'porn,',
#   'the…',
#   'the',
#   'Staten',
#   'Staten',
#   'space.',
#   'my',
#   'when',
#   '’87.”'],
#  'SNL': ['my'],
#  'my': ['first',
#   'dressing',
#   'hoodie',
#   'God.',
#   'eyes,',
#   'sight.”',
#   'word.”',
#   'attention',
#   'friends',
#   'friends',
#   'asshole',
#   'nephew',
#   'God!”',
#   'friend,',
#   'hand',
#   'fingers,',
#   'son',
#   'pants',
#   'dick,',
#   'mom’s',
#   'gay',
#   'mom’s',
#   'house',
#   'situation.',
#   'mom,',
#   'own',
#   'head,',
#   'roommate',
#   'buddies',
#   'buddy',
#   'buddy',
#   'ex.',
#   'friends',
#   'dick.',
#   'dick',
#   'life',
#   'big',
#   'dad,',
#   'mom,',
#   'sister',
#   'mom',
#   'sister,',
#   'dad',
#   'dad',
#   'dad',
#   'dad’s',
#   'dad',
#   'dad’s',
#   'dad,',
#   'dad,”',
#   'dad',
#   'dad',
#   'stummy',
#   'ways',
#   'dad,',
#   'dad.”',
#   'dad',
#   'lungs,',
#   'soul',
#   'denim',
#   'throat',
#   'homie'],
#  'first': ['year,', 'time', 'time', 'time'],
#  'year,': ['and', 'and'],
#  'and': ['this',
#   'it’s',
#   'I-I',
#   'happy',
#   'this',
#   'at',
#   'want',
#   'I-I',
#   'as',
#   'talking',
#   'writers',
#   'I',
#   'I',
#   'I’m',
#   'then',
#   'points',
#   'goes,',
#   'I',
#   'I',
#   'they’re',
#   'now',
#   'I',
#   'fired',
#   'wild',
#   'nobody',
#   'whatever,',
#   'I',
#   'Lorne’s',
#   'he’s',
#   'he',
#   'told',
#   'I',
#   'he',
#   'I',
#   'I',
#   'with',
#   'it',
#   'then',
#   'said,',
#   'you',
#   'especially',
#   'I',
#   'I',
#   'it–',
#   'you',
#   'you’re',
#   'it',
#   'then',
#   'started',
#   'their',
#   'then',
#   'the',
#   'I',
#   'I',
#   'started,',
#   'I,',
#   'I',
#   'I',
#   'you',
#   'we’ll',
#   'shit',
#   'out',
#   'a',
#   'do',
#   'then',
#   'just',
#   'I’m',
#   '“shove',
#   'they’re',
#   'you’re',
#   'he’d',
#   'at',
#   'the',
#   'then…',
#   'then',
#   'then',
#   'you’re',
#   'I’m',
#   'I’m',
#   'a',
#   'gay',
#   'be',
#   'then',
#   'a-all',
#   'be',
#   'be',
#   'I',
#   'I’m',
#   'does',
#   'then',
#   'goes,',
#   'be',
#   'does',
#   'reg–',
#   'he’s',
#   'registra–',
#   'tell',
#   'then,',
#   'unfortunately,',
#   'my',
#   'we',
#   'stuff',
#   'then',
#   'then',
#   'then',
#   'continuing',
#   'I',
#   'I',
#   'people',
#   'information.',
#   'then',
#   'that’s',
#   'that',
#   'I',
#   'a',
#   'she',
#   'stuff,',
#   'this',
#   'hopped',
#   'then',
#   'I',
#   'then',
#   'my',
#   'I',
#   'then',
#   'make',
#   'he',
#   'I',
#   'my',
#   'then,',
#   'they',
#   'swim',
#   'my',
#   'kids',
#   'I',
#   'you’re',
#   'you,',
#   'it,',
#   'do',
#   'we’re',
#   'you',
#   'the',
#   'I',
#   'he',
#   'did',
#   'putting',
#   'he’s',
#   'then',
#   'I',
#   'I',
#   'your',
#   'you',
#   'it,',
#   'he',
#   'your',
#   'I’m',
#   'then',
#   'he',
#   'then',
#   'lose'],
#  'this': ['is',
#   'is',
#   'was',
#   'is',
#   'conversation,',
#   'is',
#   'conversation.”',
#   'conversation',
#   'the',
#   'guy',
#   'shit',
#   'angle',
#   'is',
#   'was,',
#   'little…',
#   'little',
#   'an',
#   'is',
#   'fuckin’',
#   'certain',
#   'gentleman',
#   'guy,',
#   'big',
#   'guy,',
#   'guy',
#   'isn’t,',
#   'is',
#   'isn’t',
#   'stuff?',
#   'is',
#   'shit',
#   'information,',
#   'even?',
#   'even?”',
#   'thing.',
#   'place',
#   'guy',
#   'money',
#   'fame',
#   'is',
#   'is,',
#   'dude,',
#   'guy.',
#   'is',
#   'wedding.',
#   'girl,',
#   'before.',
#   'girl,',
#   'just',
#   'girl',
#   'information?”'],
#  'is': ['that',
#   'a',
#   'a',
#   'what',
#   'a',
#   'a',
#   'to',
#   'fuckin’',
#   'damn',
#   'one',
#   'that',
#   'sick!',
#   'awesome!',
#   'a',
#   'a',
#   'different',
#   'different,',
#   'just',
#   'very',
#   'from,',
#   'very',
#   'war.”',
#   'this?',
#   'gonna',
#   'this?”',
#   'this?',
#   'crazy.”',
#   'this?”',
#   'this?”',
#   'fuckin’',
#   'that,',
#   'it',
#   'Dan',
#   'pretty',
#   'what',
#   'funny.”',
#   'self-aware.”',
#   'hard',
#   'people,',
#   'a',
#   'this.',
#   'I',
#   'what',
#   'a',
#   'I’m',
#   'catchy.',
#   'very',
#   'the',
#   'a',
#   'the',
#   'disappointed.',
#   'dark.',
#   'like,',
#   'that?',
#   'on',
#   'a',
#   'a',
#   'how',
#   'how',
#   'like',
#   'not…',
#   'not',
#   'this'],
#  'that': ['story.',
#   'I',
#   'I',
#   'you',
#   'guy',
#   'fuckin’',
#   'you',
#   'with',
#   'you',
#   'it',
#   'fucking',
#   'office,',
#   'sucks,',
#   'for,',
#   'make',
#   'old',
#   'he',
#   'weed?',
#   'I',
#   'doesn’t',
#   'corner',
#   'joke',
#   'talk,',
#   'dinner',
#   'guys',
#   'little',
#   'no',
#   'is,',
#   'no–',
#   'against',
#   'would',
#   '-when',
#   'weird',
#   'a-arrives',
#   'I',
#   'guy.',
#   'guy.',
#   'guy,',
#   'boy?',
#   'he’s',
#   'gay',
#   'fuckin’',
#   'just',
#   'day',
#   'were',
#   'a',
#   'call.',
#   'I',
#   'I',
#   'lady,',
#   'lady…',
#   'was',
#   'right',
#   'to',
#   'guy,',
#   'understood',
#   'must’ve',
#   'with',
#   'fucking',
#   'a',
#   'guy',
#   'guy',
#   'guy',
#   'guy.',
#   'guy',
#   'Ariana',
#   'like…”',
#   'song',
#   'shit.”',
#   'I',
#   'she',
#   'was,',
#   'was',
#   'shit?',
#   'so',
#   'so',
#   'every',
#   'sees',
#   'reads.',
#   'sound?',
#   'before',
#   '’cause',
#   'is,',
#   'shit.',
#   'you',
#   'they',
#   'may,',
#   'make',
#   'can',
#   'is',
#   'you',
#   'a',
#   'knife'],
#  'story.': ['-So,', 'Is'],
#  '-So,': ['it’s,'],
#  'it’s,': ['like,', 'like,', 'uh,'],
#  'like,': ['2014',
#   'a',
#   'holding',
#   'a',
#   'cool',
#   'they',
#   'clearly',
#   '“I',
#   'ruin',
#   'I',
#   'so',
#   '“That',
#   '“No,',
#   '“Oh,',
#   '“Hey,',
#   '“Oh,',
#   '“Now',
#   'you',
#   '“You',
#   'how',
#   'you',
#   'divide.',
#   '“Sit',
#   '“Uh,',
#   '“I’m',
#   'Louis',
#   'awkward',
#   'watch,',
#   '“All',
#   '“I’ll',
#   '“No',
#   '“Oh,',
#   '“Yeah.”',
#   '“Oh,',
#   'am',
#   '“No.”',
#   '“Why?”',
#   '“I',
#   'with',
#   'Louis',
#   'one',
#   'why',
#   '“This',
#   'sit',
#   'five',
#   'jerk',
#   '“You’re',
#   'hearin’',
#   'I',
#   'if',
#   'you',
#   'whipped',
#   'lit',
#   '“Oh,',
#   '“Yo,',
#   '“You',
#   '“No,',
#   '“Wow,',
#   'the',
#   '“Bro,',
#   '“Oh,',
#   '“Yo,',
#   '“Yo,',
#   'shits',
#   'you',
#   'a',
#   'you',
#   '“Wow,',
#   '“I',
#   '-“Son',
#   '“Bleh,”',
#   '“Forensic',
#   'going',
#   'you',
#   '“This',
#   'we',
#   'grabbed',
#   'sucking',
#   'good.',
#   '“No!',
#   'a',
#   'grab',
#   '“Hey,',
#   'have',
#   '“No,',
#   '“I',
#   '“Oh,',
#   'yank',
#   'if',
#   'porn',
#   'a',
#   'we',
#   'you',
#   'a',
#   'screaming',
#   'luckily,',
#   'a',
#   'speed',
#   'punching',
#   '“Aw,',
#   '“Who',
#   'afraid,',
#   'so',
#   'got',
#   'a',
#   'shove',
#   'a',
#   '“Yeah.',
#   'rubbing',
#   '“Ooh,',
#   '“No.',
#   '“Hey,',
#   '“No,”',
#   '“Cool!”',
#   '“Hey,',
#   'the',
#   '“Ah.”',
#   'I',
#   'all',
#   'ripped',
#   '“What',
#   '“What–',
#   '“Hey,',
#   '“You',
#   '“What?',
#   'um,',
#   'a',
#   'a',
#   'nothing',
#   'I’ll',
#   'a',
#   '“Yeah,',
#   '“Hey,',
#   '“Yeah,',
#   '“Aw,',
#   '“Well,',
#   'confirmed?',
#   'everybody',
#   '“Mm,',
#   'cuddling',
#   'there’s',
#   'there’s',
#   'run',
#   'squeeze',
#   'slap',
#   '“Damn,',
#   'at',
#   'you',
#   'walk',
#   'tug',
#   '“Nice,',
#   'it',
#   '“Sorry,',
#   'straight',
#   'grab',
#   '“It’s',
#   'well,',
#   'Billy',
#   '“License',
#   'words',
#   'Twitter,',
#   'explain',
#   '“I',
#   'go',
#   'I',
#   'people',
#   'threatening',
#   'shoot',
#   '“What',
#   '“Sure.',
#   '“Yeah,',
#   'politicians',
#   '“Aw,',
#   '“Fuck,',
#   '“This',
#   '“This',
#   '“This',
#   '“What',
#   '“All',
#   'a',
#   '“Okay.',
#   '“Ha-ha-ha.',
#   'uh,',
#   '“You',
#   '“Yeah.”',
#   'the',
#   '“Yeah,',
#   'a',
#   '“What?”',
#   '“Pete,',
#   '“Fuck!”',
#   '“Dude,',
#   'being',
#   'fuckin’,',
#   'all-of-a-sudden',
#   '“Oh!”',
#   '“Aw,',
#   '“You',
#   '“No!',
#   '“Well,',
#   '“It’s',
#   'most',
#   'Ariana',
#   '“Yo,',
#   'fair',
#   'a',
#   'a',
#   '“Pete,',
#   '“Yeah,',
#   '“Pete,',
#   'a',
#   '“Can',
#   '“What',
#   'taken',
#   '“Dude,',
#   '“Bro,',
#   '“I',
#   'behalf',
#   'super',
#   '“Yeah,',
#   'nice',
#   '“Aw,',
#   '“Sorry',
#   '“Ah.”',
#   '“Huge',
#   '“Why?',
#   '“Wow.',
#   'the',
#   'a',
#   'people',
#   '“Is',
#   'seven',
#   'kids',
#   '“Yo.',
#   '“Yeah.',
#   'shoot',
#   'do,',
#   'research',
#   'hang',
#   'the',
#   '“Look',
#   '“Aw,',
#   '“Oh,',
#   'if',
#   'threw',
#   'came',
#   'you',
#   'way',
#   'I’ll',
#   '“Your',
#   'play',
#   '“There’s',
#   '“Yeah,',
#   '–',
#   '“That’s',
#   '“I',
#   '“Tell',
#   '“Oh,',
#   '“What?”',
#   '“Oh,',
#   '“No,',
#   'you',
#   'finished',
#   '“I’m',
#   'telling',
#   '“No,',
#   'you',
#   'I',
#   '“All',
#   '“I’m',
#   '“Let’s',
#   '“Tell',
#   '“Do',
#   '“I',
#   '“Okay.',
#   'I',
#   '“So,',
#   'fix',
#   'fuck',
#   'shakes.',
#   '“It',
#   '“We’re',
#   '“Cool,',
#   '“No.',
#   '“So',
#   '‘Where',
#   '‘Where',
#   '“So',
#   '“Yo.',
#   '“I',
#   'layin’',
#   '“Isn’t',
#   '“No!',
#   'find',
#   'pay'],
#  '2014': ['or'],
#  'or': ['’15,',
#   'brother,',
#   'quite',
#   'floor',
#   'not,',
#   'you',
#   'something',
#   'floor',
#   'something.',
#   'something.',
#   'whatever?”',
#   'whatever,',
#   'something',
#   'whatever,”',
#   'whatever.',
#   'whatever,”',
#   'whatever',
#   'the',
#   'whatever…'],
#  '’15,': ['uh,'],
#  'uh,': ['and',
#   'I',
#   'in',
#   'so',
#   '“Fuck',
#   'into',
#   'looks',
#   'as',
#   'came',
#   'you',
#   'you',
#   'the',
#   'your',
#   'that',
#   'had',
#   'I’m',
#   'they',
#   'bother',
#   'and',
#   '’cause',
#   'my',
#   'happened',
#   'the',
#   'his',
#   'so,',
#   'h-he’s',
#   'you',
#   'how',
#   'everything',
#   'was',
#   'one,',
#   'lady',
#   'this',
#   'quite',
#   'or–',
#   'apparently.',
#   'that',
#   'to',
#   'the',
#   'we’re,',
#   't-to',
#   'at',
#   'usually',
#   'o-on',
#   'your',
#   'comfortable',
#   'you',
#   'I',
#   'y-your',
#   'there’s',
#   'I',
#   'where,',
#   'you',
#   '“Oh,',
#   'I’m',
#   'it',
#   'straight',
#   'I',
#   'makin’',
#   'I',
#   '’cause',
#   'yeah,',
#   'with',
#   'and',
#   'i-if',
#   'but,',
#   'you',
#   'as',
#   'I',
#   'you',
#   'one',
#   '“Hey,',
#   'that–',
#   'Ariana.',
#   'like…',
#   'girl.”',
#   'we’ll',
#   'my–',
#   'that,',
#   'I',
#   'she',
#   'kids–',
#   'thing',
#   'that',
#   'all',
#   'his',
#   'and',
#   '“So,'],
#  'it’s': ['the',
#   'really',
#   'just…',
#   'taking',
#   'damn',
#   'very',
#   'weird',
#   'not',
#   'better.',
#   'just',
#   'really',
#   'my',
#   'the',
#   'pretty',
#   'over.',
#   'very',
#   'the',
#   'like',
#   'just–',
#   'all',
#   'a',
#   'just',
#   'a',
#   'kinda',
#   'cool.',
#   'just,',
#   'fucking'],
#  'the': ['finale',
#   'time,',
#   'time.',
#   'time,',
#   'time.',
#   'time,',
#   'elevators,',
#   'cast',
#   'way',
#   'other',
#   'elevators',
#   'way',
#   'button,',
#   'next',
#   'phone,',
#   'ones',
#   'back',
#   'door,',
#   'rumors',
#   'amount',
#   'office',
#   'other',
#   'year?”',
#   'best',
#   'time,',
#   'room',
#   'mirror?',
#   'pitch-black.',
#   'mirror,',
#   'corner',
#   'top.',
#   'harder',
#   'exact',
#   'same.',
#   'other',
#   'time.',
#   'other',
#   'time.”',
#   'shower.”',
#   'shower,',
#   'other',
#   'way',
#   'other',
#   'room.',
#   'first',
#   'mic,',
#   'lot',
#   'first',
#   'guy’s',
#   'guy,',
#   'vagina.',
#   'thing',
#   'vagina',
#   'same.',
#   'two',
#   'guy,',
#   'girl,',
#   'most',
#   'Banana',
#   'dick',
#   'best',
#   'dick',
#   'other',
#   'dick',
#   'dicks',
#   'enjoyment',
#   'pain',
#   'same',
#   'next',
#   'fuck',
#   'doctor,',
#   'most',
#   'world,',
#   'basement.',
#   'u-upper',
#   'common',
#   'cool',
#   'guy',
#   'same',
#   'streets?',
#   'streets',
#   'same',
#   'fondlers…',
#   'fondlers,',
#   'gayness,',
#   'ass,',
#   'fight',
#   'fuck?”',
#   'entire',
#   'way',
#   'officer’s',
#   'fuck',
#   'Internet.”',
#   'Internet,',
#   'face,',
#   'face.',
#   'amount',
#   'fuck',
#   'roast',
#   'same',
#   'glasses',
#   'Crenshaw',
#   'floor',
#   'fuckin’',
#   'last',
#   'floor.”',
#   '12',
#   'fuck,',
#   'Crenshaw',
#   'first',
#   'floor,',
#   'joke',
#   'war',
#   'great',
#   'war,',
#   'only',
#   'votes',
#   'confidence',
#   'cover',
#   'cover',
#   'giggles.',
#   'Year,',
#   'back',
#   'head',
#   'last',
#   'back',
#   'head.',
#   'nine-year-olds.',
#   'city?',
#   'time,',
#   'picture',
#   'song.',
#   'only',
#   'only',
#   'entire',
#   'outside,',
#   'rest',
#   'fuck',
#   'fuck',
#   'show',
#   'state',
#   'government',
#   'money,',
#   'death',
#   'sentiment,',
#   'pool,',
#   'summer.',
#   'thing–',
#   'world’s',
#   'cab',
#   'biggest',
#   'tree!”',
#   'dump?”',
#   'garbage?”',
#   'bathtub,',
#   'stories',
#   'stories',
#   'man,',
#   'same',
#   'way',
#   'way',
#   'other',
#   'decider',
#   'new',
#   'time!”',
#   'third',
#   'coolest',
#   '’90s,',
#   'hydrant.”',
#   'area,”',
#   'one',
#   'six-speed',
#   'pussy',
#   'compound',
#   'heartless',
#   'show’s',
#   'only',
#   'guy',
#   'Poconos',
#   'bed,',
#   'Poconos,',
#   'wedding,',
#   'Poconos,',
#   'story',
#   'wedding.',
#   'hotel',
#   'bathroom.”',
#   'room,',
#   'dark.',
#   'lights.',
#   'free',
#   'fuck',
#   'jokes'],
#  'finale': ['of'],
#  'of': ['SNL,',
#   'the',
#   'that.”',
#   'the',
#   'a',
#   'weed,',
#   'weed',
#   'my',
#   'my',
#   'the',
#   'women.”',
#   'the',
#   'shit.',
#   'a',
#   'a',
#   'them',
#   'breath,',
#   'movement',
#   'the',
#   'a',
#   'gay',
#   'Gushers.',
#   'gay',
#   'parking',
#   'gay',
#   'power.',
#   'you.',
#   'you',
#   'here,',
#   'shit.',
#   'trouble.',
#   'this',
#   'this',
#   'stuff',
#   'the',
#   'yourself,',
#   'everybody',
#   'paper',
#   'faces,',
#   'humor.”',
#   'a',
#   'my',
#   'that,',
#   'it,',
#   'his',
#   'America’s',
#   'the',
#   'her',
#   'Vogue',
#   'Vogue',
#   'the',
#   'the',
#   'the',
#   'them',
#   'people',
#   'it,',
#   'my',
#   'all,',
#   'my',
#   'here.',
#   'money.',
#   'money.',
#   'money,',
#   'all',
#   'their',
#   'the',
#   'the',
#   'you',
#   'all.',
#   'the',
#   'it.',
#   'a'],
#  'SNL,': ['and'],
#  'I-I': ['was',
#   'was',
#   'didn’t',
#   'can’t',
#   'was',
#   'would',
#   'go',
#   'slide',
#   'did',
#   'don’t',
#   'didn’t'],
#  'was': ['so',
#   'just',
#   'hosting,',
#   'someone',
#   'someone',
#   'hosting,',
#   'just',
#   'leaving',
#   'just,',
#   'like,',
#   'like,',
#   'alarming',
#   'like,',
#   'like,',
#   'like,',
#   'just',
#   'just',
#   'like,',
#   'walking,',
#   'like,',
#   'just,',
#   'quiet,',
#   'like,',
#   'like,',
#   'like,',
#   'like…',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'gonna',
#   'him.',
#   'all',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'babysitting,',
#   'just',
#   'like,',
#   'like,',
#   'from',
#   'sayin’.',
#   'makin’,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'me',
#   'watching',
#   'it?',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'trying',
#   'a',
#   'like,',
#   'just',
#   'bored,',
#   'like,',
#   'like…',
#   'that',
#   'get–',
#   'getting',
#   'like,',
#   'like,',
#   'really',
#   'like,',
#   'like,',
#   'a',
#   'like,',
#   'called.',
#   'told',
#   'right.',
#   'a',
#   'seven,',
#   'little,',
#   'the',
#   'so',
#   'her',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'a',
#   'a',
#   'the',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'gonna',
#   'like,',
#   'like,',
#   'fuckin’',
#   'like,',
#   'like,',
#   'like,',
#   'just'],
#  'so': ['shocked',
#   'he',
#   'I',
#   'I',
#   'I',
#   'high,',
#   'I',
#   'he',
#   'I',
#   'maybe',
#   'much',
#   'do',
#   'I',
#   'I',
#   'he',
#   'I-I',
#   'close',
#   '“banging”',
#   'fucking',
#   'much,',
#   'that',
#   'I',
#   'that',
#   'I',
#   'right',
#   'it',
#   'that–',
#   'that',
#   'lucky,',
#   'I',
#   'I',
#   'the',
#   'difficult.',
#   'I',
#   'I’m',
#   'I’m',
#   'many'],
#  'shocked': ['and'],
#  'happy': ['that'],
#  'I': ['didn’t',
#   'get',
#   'can’t–',
#   'still',
#   'was',
#   'smoked',
#   'was',
#   'was',
#   'don’t',
#   'don’t',
#   'exist,',
#   'just',
#   'closed',
#   'walked',
#   'could',
#   'press',
#   'was,',
#   'was',
#   'probably…',
#   'go',
#   'get',
#   'have',
#   'was',
#   'answered',
#   'was',
#   'was',
#   'thought,',
#   'was',
#   'was',
#   'was',
#   'was',
#   'open',
#   '’cause,',
#   'look,',
#   'look',
#   'don’t',
#   'do,',
#   'was',
#   'saw,',
#   'don’t',
#   'think',
#   'read',
#   'said,',
#   'guess,',
#   'guess,',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'fired?”',
#   'was',
#   'don’t',
#   'don’t',
#   'had',
#   'even',
#   'was',
#   'smoke',
#   'had',
#   'read:',
#   'went,',
#   'mean.',
#   'didn’t',
#   'jerk',
#   'do.',
#   'didn’t',
#   'just',
#   'financially',
#   'wasn’t',
#   'got',
#   'was',
#   'had',
#   'was',
#   'can’t',
#   'don’t',
#   'cry',
#   'gotta',
#   'don’t',
#   'don’t',
#   'hop',
#   'love',
#   'microdose',
#   'speak',
#   'love',
#   'was',
#   'was…',
#   'can’t',
#   'was',
#   'was',
#   'definitely',
#   'was',
#   'know',
#   'know',
#   'was',
#   'have.”',
#   'think',
#   'think',
#   'think–',
#   'think',
#   'don’t',
#   'know',
#   'guess',
#   'know',
#   'grew',
#   'just',
#   'felt',
#   'wasn’t',
#   'knew,',
#   'didn’t',
#   'said,',
#   'wouldn’t',
#   'hope',
#   'would',
#   'wore',
#   'don’t.',
#   'always',
#   'found',
#   'look',
#   'have',
#   'know',
#   'was',
#   'guess',
#   'guess…',
#   'get',
#   'go',
#   'don’t',
#   'have',
#   'have',
#   'like,',
#   'don’t',
#   'left',
#   'don’t',
#   'love',
#   'have',
#   'live',
#   'got–',
#   'got',
#   'gotta',
#   'date',
#   'don’t',
#   'want',
#   'don’t',
#   'call',
#   'don’t',
#   'work',
#   'would',
#   'could,',
#   'wouldn’t,',
#   'don’t',
#   'always',
#   'go',
#   'go,',
#   'can’t',
#   'get',
#   'got',
#   'thought',
#   'get',
#   'get',
#   'got',
#   'got',
#   'made',
#   'was–',
#   'didn’t',
#   'did',
#   'don’t…',
#   'don’t',
#   'can’t,',
#   'was',
#   'go',
#   'made',
#   'kinda',
#   'didn’t',
#   'should',
#   'didn’t',
#   'said,',
#   'don’t',
#   'get',
#   'was',
#   'was',
#   'was',
#   'got',
#   'just',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'always',
#   'just…',
#   'was',
#   'hope',
#   'don’t',
#   'wrote',
#   'just',
#   'was',
#   'think',
#   'was',
#   'was',
#   'go',
#   'try',
#   'said,',
#   'appreciate',
#   'also',
#   'got',
#   'got',
#   'say,',
#   'do.',
#   'do',
#   'remember',
#   'remember',
#   'said.',
#   'said,',
#   'go,',
#   'know',
#   'said',
#   'just',
#   'don’t',
#   'have',
#   'don’t',
#   'was',
#   'hate',
#   'think,',
#   'could’ve',
#   'did',
#   'did',
#   'did',
#   'am',
#   'apologize',
#   'did',
#   'did',
#   'wasn’t',
#   'just',
#   'have,',
#   'did',
#   'did',
#   'spray-painted',
#   'don’t',
#   'like',
#   'did',
#   'was',
#   'was',
#   'was',
#   'got',
#   'don’t',
#   'walked',
#   'was',
#   'have',
#   'can’t',
#   'was',
#   'kinda',
#   'was',
#   'didn’t',
#   'knew',
#   'would’ve',
#   'started',
#   'would’ve,',
#   'didn’t',
#   'love',
#   'love',
#   'actually',
#   'like',
#   'don’t–',
#   'don’t',
#   'was',
#   'didn’t',
#   'got',
#   'don’t',
#   'thought',
#   'thought',
#   'said',
#   'was',
#   'had',
#   'didn’t',
#   'was',
#   'didn’t',
#   'have',
#   'was',
#   'had',
#   'do',
#   'retorted,',
#   'don’t',
#   'should',
#   'won.',
#   'was',
#   'don’t',
#   'remember',
#   'remember',
#   'was,',
#   'remember',
#   'got',
#   'have',
#   'fill',
#   'wouldn’t',
#   'appreciate',
#   'don’t',
#   'did',
#   'had',
#   'had',
#   'had',
#   'had',
#   'knew',
#   'was',
#   'had',
#   'don’t',
#   'was',
#   'figured',
#   'mean?',
#   'like',
#   'guess',
#   'had',
#   'was',
#   'was',
#   'not',
#   'was',
#   'wasn’t',
#   'heard,',
#   'guess',
#   'just',
#   'like',
#   'was',
#   'said,',
#   'grew',
#   'always',
#   'didn’t',
#   'didn’t',
#   'appreciate',
#   'want',
#   'would',
#   'wanna',
#   'was',
#   'was',
#   'was',
#   'don’t',
#   'created',
#   'was',
#   'was',
#   'look',
#   'look',
#   'don’t',
#   'just',
#   'go',
#   'had',
#   'was',
#   'just',
#   'was',
#   'come,',
#   'see',
#   'see',
#   'turn',
#   'go,',
#   'was…',
#   'was',
#   'have',
#   'fuck',
#   'was'],
#  'didn’t': ['get',
#   'happen.”',
#   'know',
#   'want',
#   'say',
#   'really–',
#   'really',
#   'think',
#   'pick',
#   'get',
#   'want',
#   'know',
#   'know',
#   'really…',
#   'like',
#   'work',
#   'work',
#   'like',
#   'even',
#   'miss',
#   'know',
#   'know'],
#  'fired,': ['and'],
#  'a': ['feeling',
#   'very',
#   'joint,',
#   'bunch',
#   'conversation,',
#   'sudden,',
#   'me',
#   'phone',
#   'year,',
#   'shit,',
#   'big',
#   'pussy,',
#   'lot',
#   'man',
#   'conversation',
#   'yearly',
#   'long',
#   'fuckin’',
#   'text,',
#   'mom',
#   'blunt,',
#   'kid,',
#   'dad.',
#   'call.',
#   'job?”',
#   'kid.”',
#   'job.”',
#   'kid.',
#   'smaller',
#   'bitch.”',
#   'roller',
#   'second.',
#   'joke,',
#   'comedy',
#   'town',
#   'debriefing,',
#   'mom',
#   'sister,',
#   'lot',
#   'couple',
#   'little',
#   'suit,',
#   'nice',
#   'divorced',
#   'repertoire',
#   'girl’s',
#   'landslide.',
#   'lot.',
#   'lot.',
#   'sudden,',
#   'lot',
#   'lot',
#   'more',
#   'gay',
#   'straight',
#   'whole',
#   'package',
#   'lot',
#   'technicality?',
#   'little',
#   'lesbian',
#   'lot.',
#   'piece',
#   'lot',
#   'guy',
#   'special',
#   'thing.',
#   'roast',
#   'bunch',
#   'sense',
#   'dick,',
#   'sport.”',
#   'harmless,',
#   'hit',
#   'porno.”',
#   'cab.',
#   'Netflix',
#   'little',
#   'hit',
#   'porno.”',
#   'sudden,',
#   'war',
#   'war,',
#   'hit',
#   'porno,',
#   'war',
#   'fucking',
#   'sandwich.',
#   'week',
#   'car',
#   'bad',
#   'Republican',
#   'lock',
#   'household',
#   'distraction.”',
#   'Drake',
#   'competition,',
#   'little',
#   'shot',
#   'nine-year-old',
#   'ponytail.',
#   'really',
#   'very,',
#   'person.',
#   'medium',
#   'dermatologist',
#   'rough',
#   'slap.',
#   'slap.',
#   'good',
#   'common',
#   'nice…',
#   'nice,',
#   'step',
#   'fucking',
#   'great,',
#   'nice',
#   'nice',
#   'nice',
#   'genius.',
#   'very',
#   'lifetime',
#   'family',
#   'fireman.',
#   'little',
#   'lot',
#   'little',
#   'pool',
#   'pool,',
#   'nice',
#   'weird',
#   'pool,',
#   'pool.”',
#   'pool',
#   'fucking',
#   'park',
#   'fucking',
#   'good',
#   'Marlboro',
#   'Staten',
#   'reason',
#   'third',
#   'third',
#   'kid',
#   'third',
#   'hero,',
#   'fuckin’',
#   'man',
#   'legend.',
#   'good',
#   'bitch',
#   'bitch',
#   'dog',
#   'pulse',
#   'better',
#   'wedding',
#   'story',
#   'story',
#   'wedding,”',
#   'heart-shaped',
#   'quarter',
#   'wedding,',
#   'good',
#   'room,',
#   'room',
#   'pussy.”',
#   'pussy.”',
#   'sudden,',
#   'cigarette',
#   'great',
#   'horrible',
#   'good',
#   'hole'],
#  'feeling': ['that', 'sickly'],
#  'relive': ['every'],
#  'every': ['week.',
#   'girl',
#   'girl',
#   'girl',
#   'time',
#   'girl',
#   'cannon',
#   'day',
#   'summer.',
#   'which'],
#  'week.': ['-I'],
#  '-I': ['get…', 'was'],
#  'get…': ['Just,'],
#  'Just,': ['it–'],
#  'it–': ['it’s', 'it’s', 'it–', 'it'],
#  'really': ['awesome.',
#   'tight,',
#   'confused,',
#   'sorry',
#   'sad,',
#   'affected',
#   'bother',
#   'easy.',
#   'know,',
#   'hurts,',
#   'mean.',
#   'powerful',
#   'sorry.',
#   'weird'],
#  'awesome.': ['I'],
#  'can’t–': ['I'],
#  'still': ['can’t', 'teething,', 'applies'],
#  'can’t': ['believe',
#   'even',
#   'even',
#   'wait',
#   'believe',
#   'tell,',
#   'fight',
#   'walk',
#   'find'],
#  'believe': ['it.', 'we’re', 'it'],
#  'it.': ['It’s',
#   'Uh…',
#   'They’re',
#   'You',
#   'That’s',
#   'Probably',
#   'Didn’t',
#   'Man,',
#   'Um…',
#   '-Uh…',
#   'Uh…',
#   'You',
#   'Just',
#   'Uh,',
#   'So,',
#   'Thanks',
#   'Uh…'],
#  'It’s': ['very',
#   'like',
#   'just',
#   'just',
#   'not',
#   'really',
#   'an',
#   'fuckin’',
#   'that',
#   'just,',
#   'just',
#   'even',
#   'your',
#   'gonna',
#   'an',
#   'just',
#   'an',
#   'just',
#   'like',
#   'all',
#   'a',
#   'ridiculous.',
#   'just',
#   'genius!',
#   'a',
#   '’cause',
#   'just,',
#   'your',
#   'a'],
#  'very': ['funny.',
#   'well-respected',
#   'into',
#   'confused,',
#   'excited.',
#   'hard',
#   'much.',
#   'self-explanatory,',
#   'hard',
#   'lightly…',
#   'self-explanatory,',
#   'bad.',
#   'limited',
#   'minimal,',
#   'powerful',
#   'smart.',
#   'catchy.',
#   'little',
#   'smart'],
#  'funny.': ['Um,'],
#  'Um,': ['so,',
#   'anyway,',
#   'no,',
#   'sorry.',
#   'that',
#   'so…',
#   'we',
#   'anyway,',
#   'so…'],
#  'so,': ['I', 'uh,', 'like,', 'uh,', 'like,', 'uh,', 'like,', 'like,', 'you'],
#  'just': ['celebrating,',
#   'thrilled,',
#   'put',
#   'waitin’',
#   'left',
#   'trying',
#   'like,',
#   'trying',
#   'asked',
#   'like,',
#   'killed',
#   'tell',
#   'felt',
#   'really',
#   'never',
#   'the',
#   'sittin’',
#   'dead',
#   'broken.”',
#   'say',
#   'tell',
#   'never',
#   'take',
#   'kinda',
#   'tap',
#   'tell',
#   'started,',
#   'usually',
#   'imagine',
#   'start',
#   'like,',
#   'start,',
#   'pure',
#   'get',
#   '’cause',
#   '’cause',
#   'doesn’t',
#   'weird',
#   'sitting',
#   'shoot',
#   'sittin’',
#   'do',
#   'started',
#   'write,',
#   'did',
#   'did',
#   'givin’',
#   'didn’t',
#   'easier',
#   'only',
#   'dated',
#   'think',
#   'started',
#   'jokes.',
#   'fucking',
#   'pop,',
#   'except',
#   'simply',
#   'not–',
#   'very',
#   'stop',
#   'fuckin’',
#   'getting',
#   'makes',
#   'wasn’t–”',
#   'doing',
#   'thought,',
#   'start',
#   'sounds',
#   'want',
#   'with'],
#  'celebrating,': ['you'],
#  'you': ['know?',
#   'would',
#   'wanted',
#   'know,',
#   'know?',
#   'know,',
#   'stupid',
#   'tomorrow,',
#   'now,”',
#   'know,',
#   'know,',
#   'know?',
#   'know,',
#   'just',
#   'smoke',
#   'have',
#   'know?',
#   'know,',
#   'could',
#   'know,',
#   'smoke',
#   'could',
#   'smoke.”',
#   'know,',
#   'smoked',
#   'know?',
#   'know?',
#   'know,',
#   'know,',
#   'know?',
#   'want,',
#   'know?',
#   'know?',
#   'how',
#   'know,',
#   'know?',
#   'know,',
#   'can’t',
#   'can’t…',
#   'think',
#   'catch',
#   'know,',
#   'could',
#   'can',
#   'know,',
#   'know,',
#   'fuckin’',
#   'leave.',
#   'know,',
#   'know?',
#   'clean',
#   'see',
#   'might',
#   'know?',
#   'know?',
#   'just',
#   'know,',
#   'know.',
#   'have',
#   'know?',
#   'know,',
#   'just',
#   'know.',
#   'don’t',
#   'could',
#   'know,',
#   'could',
#   'know?',
#   'know,',
#   'have',
#   'know,',
#   'know?',
#   'know,',
#   'just',
#   'know,',
#   'just',
#   'should',
#   'know?',
#   'know,',
#   'know,',
#   'know.',
#   'know',
#   'know',
#   'know',
#   'like',
#   'know,',
#   'shave',
#   'don’t,',
#   'just',
#   'like',
#   'ever',
#   'wake',
#   'know?',
#   'an',
#   'know?',
#   'and',
#   'know,',
#   'know?',
#   'hate',
#   'cuddling',
#   'know?',
#   'look',
#   'know.',
#   'know',
#   'just',
#   'know?',
#   'know?',
#   'know?',
#   'know?',
#   'guys',
#   'know?',
#   'know,',
#   'know,',
#   'know,',
#   'might',
#   'were.”',
#   'think',
#   'turn',
#   'know,',
#   'know,',
#   'do,',
#   'just',
#   'know,',
#   'make',
#   'know?',
#   'know?',
#   'lose',
#   'could',
#   'go',
#   'go',
#   'go',
#   'get',
#   'know,',
#   'hoped',
#   'know,',
#   'know,',
#   'know,',
#   'know?',
#   'to',
#   'fucked',
#   'again',
#   '’cause',
#   'know,',
#   'know,',
#   'know?',
#   'that.',
#   'know,',
#   'were,',
#   'as',
#   'know?',
#   'know,',
#   'do',
#   'imagine',
#   'imagine',
#   'imagine–',
#   'imagine',
#   'know,',
#   'gotta',
#   'know,',
#   'know,',
#   'but…”',
#   'imagine',
#   'imagine',
#   'ask',
#   'have?”',
#   'know,',
#   'know,',
#   'know',
#   'can',
#   'say.',
#   'know,',
#   'can',
#   'entered',
#   'knew',
#   'Staten',
#   'had',
#   'know?',
#   'know,',
#   'an',
#   'know?',
#   'know?',
#   'yelling,',
#   'are',
#   'can',
#   'know,',
#   'know?',
#   'too',
#   'know,',
#   'picture',
#   'have',
#   'to',
#   'go',
#   'put',
#   'know,',
#   'know,',
#   'know,',
#   'know?',
#   'remember',
#   'to',
#   'know.',
#   'know?',
#   'guys'],
#  'know?': ['Louis',
#   'So',
#   'So',
#   'Fuckin’…',
#   'I',
#   '‘Cause',
#   'Like,',
#   'One',
#   'That’s',
#   'And',
#   '-And',
#   '-Is',
#   'There’s',
#   'You',
#   'Plus,',
#   'Yeah.',
#   'You’re',
#   'Uh,',
#   'You',
#   'Didn’t',
#   'You',
#   'Like,',
#   'I',
#   'You',
#   'Like',
#   'So',
#   '‘Cause,',
#   'And',
#   'If',
#   'You’ll',
#   'Different',
#   'You',
#   'I',
#   'I',
#   'Uh,',
#   'But',
#   'Uh,',
#   'So,',
#   'This',
#   'If',
#   'Not',
#   'General',
#   'It’s',
#   'So',
#   'As',
#   'I',
#   'She',
#   'I',
#   'They’re',
#   'And',
#   'So',
#   '‘Cause',
#   '-“Told',
#   'And',
#   'As',
#   '“What’d',
#   'Um…',
#   'We',
#   'He',
#   'I',
#   'I',
#   'Uh…'],
#  'hosting,': ['and', 'and'],
#  'at': ['the',
#   'the',
#   'the',
#   'all,',
#   'me',
#   'work,',
#   'the',
#   'the',
#   'all.',
#   'the',
#   'all.',
#   'first,',
#   'all.',
#   'all.',
#   'all.',
#   'all.',
#   'the',
#   'SNL.”',
#   'school',
#   'the',
#   'seven',
#   'a',
#   'the',
#   'this'],
#  'time,': ['Louis', 'he', 'it', 'like,', 'and', 'you', 'me'],
#  'was,': ['like,', 'like,', 'like,', 'like,', 'like,', 'like,', 'like,'],
#  'well-respected': ['comedian.'],
#  'comedian.': ['Like,'],
#  'Like,': ['at',
#   'yeah.',
#   'you',
#   'this',
#   'really?”',
#   'I',
#   'I',
#   'you',
#   'I',
#   'the',
#   'I',
#   'my',
#   'here’s',
#   'I',
#   'I’m',
#   'it',
#   'I',
#   '“Hey!”',
#   'this',
#   '“You’re',
#   'it’s',
#   'I',
#   'he',
#   'fuck'],
#  'time.': ['Like,', 'At', 'Eventually,', 'We’re'],
#  'yeah.': ['At',
#   'I',
#   'Sorry.',
#   'I',
#   'Also,',
#   'All',
#   'Also,',
#   'Uh,',
#   'Yeah.',
#   '-Um…',
#   'This'],
#  'At': ['the', 'the'],
#  'he': ['was',
#   'was',
#   'looks',
#   'goes,',
#   'kinda',
#   'didn’t',
#   'told',
#   'goes,',
#   'said',
#   'goes,',
#   'was',
#   'was',
#   'jerked',
#   'would’ve',
#   'was',
#   'just,',
#   'could,',
#   'has',
#   'has',
#   'might',
#   'was',
#   'might’ve',
#   'might’ve',
#   'lost',
#   'lost',
#   'died',
#   'won',
#   'goes,',
#   'has',
#   'died',
#   'works',
#   'was',
#   'was',
#   'always',
#   'was',
#   'was',
#   'did',
#   'talks.',
#   'goes,',
#   'always',
#   'said.',
#   'was',
#   'was',
#   'goes,',
#   'goes,',
#   'goes,',
#   'goes,',
#   'ghost'],
#  'someone': ['that', 'you', 'ever'],
#  'would': ['look',
#   'fuckin’',
#   'wanna',
#   'be',
#   'be',
#   'do',
#   'never',
#   'like…',
#   'be',
#   'be',
#   'she',
#   'she',
#   'want',
#   'come',
#   'be',
#   'say',
#   'be',
#   'like',
#   'be'],
#  'look': ['up', 'stupid', 'like,', 'like', 'great!”', 'for', 'all'],
#  'up': ['to',
#   'and',
#   'a',
#   'at,',
#   'with',
#   'there?',
#   'there.',
#   'and',
#   'to',
#   'with,',
#   'with',
#   'with',
#   'on',
#   'to',
#   'to',
#   'to',
#   'that',
#   'with',
#   'with',
#   'thinking,',
#   'in',
#   'here.',
#   'and'],
#  'want': ['approval',
#   'any',
#   'that',
#   'it',
#   'to',
#   'to.”',
#   'to',
#   'any',
#   'no',
#   'to',
#   'it',
#   'you',
#   'you'],
#  'approval': ['of,', 'you'],
#  'of,': ['at', 'like,', 'and'],
#  'it': ['was',
#   'for',
#   'really',
#   'was',
#   'was',
#   'out',
#   'to',
#   'actually',
#   'out.',
#   'to',
#   'was',
#   'was',
#   'is',
#   'okay?',
#   'could',
#   'is',
#   'just–',
#   'bummed',
#   'really',
#   'cries!”',
#   'stop,',
#   'out.',
#   'cries,',
#   'up',
#   'in',
#   'would',
#   'won’t.',
#   'doesn’t.',
#   'wrong.',
#   'out',
#   'out.',
#   'right',
#   'together.',
#   'or',
#   'up',
#   'up',
#   'in',
#   'feels',
#   'really',
#   'does.',
#   'out',
#   'just',
#   'just–',
#   'never',
#   'or',
#   'only',
#   'only',
#   'doesn’t',
#   'doesn’t',
#   'is.',
#   'plays.',
#   'right',
#   'cool?',
#   'everything',
#   'at',
#   'goes,',
#   'went.',
#   'was',
#   'even',
#   'on',
#   'didn’t',
#   'didn’t',
#   'because',
#   'was',
#   'will',
#   'starts',
#   'in',
#   'all',
#   'out',
#   'burn'],
#  'wanted': ['to', 'to', 'that'],
#  'be': ['nice',
#   'in',
#   'in',
#   'weird',
#   'in',
#   'mid-,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'on',
#   'slimed.',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'listenin’',
#   'famous,',
#   'great.',
#   'fine.',
#   'mindful,',
#   'mindful',
#   'incorrect',
#   'mindful.',
#   'over',
#   'insane.',
#   'some',
#   'to',
#   'able',
#   'our',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'that',
#   'like,',
#   'a',
#   'a',
#   'embarrassing.',
#   'found,'],
#  'nice': ['to', 'lady', 'dick.”', 'lady.', 'word.”', 'penis.”', 'idea,'],
#  'you.': ['Um,', 'They’re', 'I', 'Walk', 'I’m', 'You', 'I', '♪'],
#  'anyway,': ['so', 'so', 'so'],
#  'thrilled,': ['so,'],
#  'smoked': ['a', 'so'],
#  'joint,': ['uh,'],
#  'in': ['my',
#   'the',
#   'there',
#   'and',
#   'the',
#   'front',
#   'the',
#   'the',
#   'the',
#   'the',
#   'front',
#   'the',
#   'there',
#   'the',
#   'the',
#   'them?',
#   'them”',
#   'ya?',
#   'there.',
#   'Staten',
#   'the',
#   'the',
#   'there,',
#   'Ohio…',
#   'front',
#   'my',
#   'trouble',
#   'a–',
#   'a',
#   'trouble',
#   'trouble,',
#   'politics.',
#   'the',
#   'the',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'war',
#   'Afghanistan,',
#   'Nazi',
#   'a',
#   'war',
#   'Texas.',
#   'Texas,',
#   'the',
#   'the',
#   'the',
#   'the',
#   'it.',
#   'the',
#   'your',
#   'ten',
#   'the',
#   'Africa.”',
#   'Africa',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'it,',
#   'the',
#   'my'],
#  'dressing': ['room,'],
#  'room,': ['and', 'right?', 'right?', 'I'],
#  'as': ['I', 'do', 'well', 'you', '8', 'a', 'you', 'them,'],
#  'leaving': ['to'],
#  'go': ['into',
#   'to',
#   'in',
#   'to',
#   'down.',
#   'right…',
#   'slow',
#   'upstairs,',
#   'to',
#   'up',
#   'on',
#   'to',
#   'eye',
#   'glass',
#   'glass',
#   'fuckin’',
#   'on',
#   'great.”',
#   'out',
#   'on',
#   'meet',
#   'to',
#   'fuck',
#   'back',
#   '♪\n♪'],
#  'into': ['the', 'a', 'the', 'his', 'Starbucks.', 'anything.'],
#  'elevators,': ['um…'],
#  'um…': ['Louis', 'I', '…and', 'This', 'You', 'You,'],
#  'holding': ['court'],
#  'court': ['and'],
#  'talking': ['to,'],
#  'to,': ['like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,'],
#  'bunch': ['of', 'of'],
#  'cast': ['and'],
#  'writers': ['and,'],
#  'and,': ['like,',
#   'like,',
#   'uh,',
#   'personally,',
#   'like,',
#   'uh,',
#   'uh…',
#   'like,',
#   'uh…',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'uh,',
#   'the–',
#   'like,',
#   'like,',
#   'like,',
#   'you',
#   'uh…',
#   'like,'],
#  'cool': ['people,', 'cats', 'with'],
#  'people,': ['and,', 'and', 'like,'],
#  'they': ['were,',
#   'only',
#   'just,',
#   'don’t,',
#   'say',
#   'just',
#   'put',
#   'want.',
#   'get',
#   'just',
#   'vote.',
#   'getting',
#   'would',
#   'do?”',
#   'built',
#   'got',
#   'were',
#   'never'],
#  'were,': ['like,', 'right?', 'like,', 'and', 'like,'],
#  'clearly': ['very'],
#  'conversation,': ['so', 'but,'],
#  'just,': ['like,',
#   'like,',
#   'like,',
#   'like,',
#   'you',
#   'you',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like…',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'in',
#   'I',
#   'like',
#   'like,'],
#  '“I': ['don’t',
#   'don’t',
#   'don’t',
#   'will',
#   'hate',
#   'guess',
#   'sucked',
#   'get',
#   'don’t',
#   'don’t',
#   'got',
#   'was',
#   'know'],
#  'don’t': ['want',
#   'wanna,',
#   'want',
#   'know.',
#   'think',
#   'know.”',
#   'know.',
#   'know.',
#   'know.”',
#   'think',
#   'know.',
#   'mind',
#   'know.',
#   'want',
#   'know.',
#   'think',
#   'gotta',
#   'think',
#   'know',
#   'get',
#   'find',
#   'understand,',
#   'have,',
#   'know,',
#   'you',
#   'even…',
#   'know',
#   'have',
#   'like',
#   'applaud.',
#   'clap.',
#   'like',
#   'want',
#   'want',
#   'even',
#   'like',
#   'know,',
#   'think',
#   'know.',
#   'understand',
#   'know',
#   'care',
#   'know',
#   'even',
#   'know',
#   'want',
#   'see'],
#  'any': ['part', 'other', 'smoke,', 'other', 'other', 'other'],
#  'part': ['of', 'of'],
#  'that.”': ['Like,', 'I'],
#  'know,': ['I’m',
#   'be',
#   'I',
#   '’cause',
#   'uh,',
#   'that’s',
#   'you',
#   'and',
#   'it',
#   'what',
#   '’cause',
#   'you’re',
#   'just',
#   'and',
#   '’cause,',
#   'does',
#   'be',
#   'jerking',
#   '’cause',
#   '’cause',
#   'when',
#   'so',
#   'so',
#   'where',
#   'it',
#   '’cause',
#   'what',
#   'you',
#   'fuck,',
#   'it’s',
#   'like,',
#   'all',
#   '“Yo,',
#   'so,',
#   'sometimes',
#   'and',
#   'so',
#   'but,',
#   'you',
#   'because,',
#   'the',
#   '’cause',
#   'so,',
#   'and',
#   'that',
#   'always',
#   'what’s',
#   'I-I-I',
#   'uh,',
#   'and',
#   'gay',
#   'friends',
#   'just',
#   'there’s',
#   'he,',
#   'slaps',
#   'grabs',
#   'you',
#   'do–',
#   'I',
#   'uh,',
#   'like',
#   'I',
#   'i-it’s',
#   'joke',
#   'I',
#   'um…',
#   '“He',
#   'stuff',
#   'I-I',
#   'laugh,',
#   'he',
#   'America’s',
#   'her',
#   'a-and',
#   'you',
#   'like,',
#   'just',
#   'to',
#   'to',
#   'like,',
#   'which',
#   'his',
#   'so',
#   'growing',
#   'he',
#   'I',
#   'we’re',
#   'me',
#   'maybe',
#   'she'],
#  'I’m': ['high.',
#   'just',
#   'gettin’',
#   'really',
#   'a',
#   'sorry',
#   'glad',
#   'stupid.',
#   'telling.',
#   'a',
#   'very',
#   'like,',
#   'aware.',
#   'telling',
#   'like,',
#   'told',
#   'ready',
#   'fucking',
#   'like,',
#   'like,',
#   'very,',
#   'onto',
#   'sorry.',
#   'all',
#   'against',
#   'straight.',
#   'sure',
#   'gay.”',
#   'not',
#   'pretty',
#   'very',
#   'like,',
#   'about',
#   'always',
#   'enjoying',
#   'like,',
#   'like,',
#   'pretty',
#   'gonna',
#   'gonna',
#   'going',
#   'sorry.',
#   'sorry.',
#   'sorry.',
#   'really',
#   'sorry.',
#   'from',
#   'trying',
#   'sorry.',
#   'gonna',
#   'what',
#   'heartless',
#   'back',
#   'heartless',
#   'heartless',
#   'heartless',
#   'heartless',
#   'heartless',
#   'at',
#   'with',
#   'tryin’',
#   'tryin’',
#   'like,',
#   'with',
#   'fuckin’',
#   'not',
#   'smokin’'],
#  'high.': ['I'],
#  'wanna,': ['like,'],
#  'ruin': ['it', 'Starbucks'],
#  'for': ['anybody.',
#   'sure.',
#   'a',
#   'another',
#   'sure.',
#   'all',
#   'it.',
#   'like',
#   'a',
#   'me.',
#   'gay',
#   'the',
#   'me,',
#   'certain',
#   'unpausing',
#   'coming',
#   'that',
#   'no',
#   'me,',
#   'a',
#   'the',
#   '9/11.',
#   'having',
#   'comin’.',
#   'life',
#   'life',
#   'a',
#   'your',
#   'me.',
#   'you.’',
#   'the',
#   'comin’'],
#  'anybody.': ['Or,'],
#  'Or,': ['like,'],
#  'guy': ['to',
#   'doesn’t',
#   'fucking',
#   'stuff',
#   'stuff',
#   'likes,',
#   'likes,',
#   'likes',
#   'that,',
#   'could,',
#   'Dan',
#   'has',
#   'is',
#   'is',
#   'looks',
#   'won,”',
#   'is',
#   'win,',
#   'famous',
#   'was',
#   'is',
#   'is.',
#   'ever.”',
#   'gets',
#   'gets',
#   'talks.'],
#  'know': ['I',
#   'what',
#   'what',
#   'that',
#   'it’s',
#   'you',
#   'is',
#   'boxing?',
#   'when,',
#   'that’s',
#   'when',
#   'when',
#   'that',
#   'that.',
#   'how',
#   'how',
#   'he',
#   'how',
#   'what',
#   'about',
#   'what’s',
#   'you’re',
#   'why?',
#   'if',
#   'who',
#   'what',
#   'if',
#   'he',
#   'he',
#   'I’m',
#   'you’re'],
#  'exist,': ['you'],
#  'So': ['I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'that,',
#   'just',
#   'you',
#   'it’s',
#   'we',
#   'already,',
#   'I',
#   'I',
#   'I-I',
#   'I-I',
#   'now',
#   'sometimes,',
#   'you',
#   'I',
#   'I',
#   'when',
#   'I',
#   'I',
#   'I’m'],
#  'put': ['my', 'it', 'it', 'on,', 'a'],
#  'hoodie': ['on,'],
#  'on,': ['and', 'like,', 'man.', 'like,', 'right?'],
#  'closed': ['it'],
#  'tight,': ['and'],
#  'walked': ['all', 'into'],
#  'all': ['the',
#   'of',
#   'this',
#   'those',
#   'excited.',
#   'my',
#   'the',
#   'the',
#   'I',
#   'prickly',
#   'of',
#   'chapped',
#   'for',
#   'of',
#   'of',
#   'right.',
#   'right?',
#   'the',
#   'lie',
#   'good,',
#   'good.',
#   'this',
#   'the',
#   'the',
#   'people’s',
#   'the',
#   'now',
#   'over'],
#  'way': ['around',
#   'at',
#   'up,',
#   'to',
#   'here.',
#   'different…',
#   'through,',
#   'through'],
#  'around': ['to'],
#  'other': ['side',
#   'day',
#   'room.”',
#   'complaint',
#   'day,',
#   'day.',
#   'ways,',
#   'four',
#   'way,',
#   'things',
#   'breakup,',
#   'breakup.',
#   'half',
#   'story',
#   'stories?”'],
#  'side': ['of'],
#  'elevators': ['so'],
#  'could': ['not,',
#   'creep',
#   'do',
#   'just,',
#   'get',
#   'reflect',
#   'be–',
#   'be',
#   'be',
#   'do',
#   'say,',
#   'you',
#   'do',
#   'you'],
#  'not,': ['you', 'I’ve'],
#  'all,': ['and,', 'let’s'],
#  'press': ['the'],
#  'button,': ['and'],
#  'waitin’': ['there,'],
#  'there,': ['and',
#   'right?',
#   'and,',
#   'right?',
#   'ever.',
#   'and',
#   'and',
#   'not',
#   'and',
#   'and'],
#  'then': ['all',
#   'I',
#   'he',
#   'you',
#   'you',
#   'go',
#   'you',
#   'you’re',
#   'all',
#   'the',
#   'I',
#   'there’s',
#   'your',
#   'your',
#   'I',
#   'Kyle',
#   'it’s',
#   'you',
#   'this',
#   'you',
#   'you',
#   'all',
#   'right',
#   'made',
#   'my',
#   'Fortnite',
#   'just',
#   'that',
#   'why',
#   'we’ll',
#   'my',
#   'we',
#   'we’re'],
#  'sudden,': ['Louis', 'uh,', 'right', 'I'],
#  'stops': ['his'],
#  'his': ['conversation.',
#   'office',
#   'office,',
#   'eyes,',
#   'eyes,',
#   'eyes,',
#   'dick',
#   'son',
#   'boyfriend',
#   'dick',
#   'eye',
#   'eye',
#   'eye',
#   'fuckin’',
#   'eye',
#   'eye.',
#   'stats',
#   'dick',
#   'alarm',
#   'friends,',
#   'friends',
#   'friends,',
#   'plate.',
#   'plate!',
#   'friends,',
#   'homework',
#   'plate,'],
#  'conversation.': ['He'],
#  'He': ['looks',
#   'probably',
#   'went',
#   'goes,',
#   'gave',
#   'was',
#   'was',
#   'won.',
#   'looks',
#   'could’ve',
#   'died',
#   'was',
#   'always',
#   'told',
#   'goes,',
#   'goes–',
#   'acted',
#   'goes,'],
#  'looks': ['up', 'really', 'very', 'like', 'like', 'like', 'like'],
#  'points': ['at'],
#  'goes,': ['“Look',
#   '“So…',
#   '“Yeah,',
#   '“Yeah.”',
#   '“Um,',
#   'uh,',
#   'uh,',
#   '“It’s',
#   '“So,',
#   'uh,',
#   '“Hold',
#   '“So,',
#   '“You',
#   '‘Hey,',
#   '“Now,'],
#  '“Look': ['how', 'at'],
#  'how': ['fuckin’',
#   'I',
#   'crazy',
#   'to',
#   'to',
#   'horrible',
#   'to',
#   'hard',
#   'many',
#   'was',
#   'it',
#   'he',
#   'he',
#   'they',
#   'you',
#   'half',
#   'he',
#   'the',
#   'the'],
#  'fuckin’': ['high',
#   'idiot!',
#   'high',
#   'notice.',
#   'weird.',
#   'loser.',
#   'animals.',
#   'cool.',
#   'gay',
#   'guy,',
#   'crazy.',
#   'funny,',
#   'birthdays',
#   'fair',
#   'cool',
#   'sunglasses,',
#   'Update,',
#   'eye.”',
#   'idea.',
#   'Dan',
#   'baseball',
#   'built',
#   '’98',
#   'superhero.',
#   'go!',
#   'dancing.',
#   'someone,',
#   'doing'],
#  'high': ['Pete', 'at'],
#  'Pete': ['is,', 'out'],
#  'is,': ['that',
#   'I',
#   'they’re',
#   'uh,',
#   'like,',
#   'uh,',
#   'so',
#   'you',
#   'like,',
#   'you',
#   '“Hashtag',
#   'um…',
#   'um,'],
#  'idiot!': ['Just'],
#  'Just': ['getting', 'put', 'honest,', 'doing'],
#  'getting': ['fuckin’', 'a', 'rid', 'into,', 'stabbed', 'faded', 'fucked'],
#  'work,': ['you', 'like,'],
#  'stupid': ['fuck.', 'anyway.'],
#  'fuck.': ['You’re', 'All', 'You’re', 'I'],
#  'You’re': ['gonna',
#   'gonna',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'not',
#   'gonna',
#   'so',
#   'rich.',
#   'not'],
#  'gonna': ['smoke',
#   'happen',
#   'smoke',
#   'be',
#   'come',
#   'be',
#   'go',
#   'do',
#   'get',
#   'hear',
#   'have',
#   'get',
#   'secure',
#   'be,'],
#  'smoke': ['your', 'weed.”', 'a', 'weed?”', 'away', 'from'],
#  'your': ['career',
#   'career',
#   'career.”',
#   'son',
#   'outfit.',
#   'dick',
#   'girlfriend',
#   'girl',
#   'girlfriend',
#   'eye,',
#   'face',
#   'fault',
#   'boys',
#   'dad',
#   'family',
#   'own',
#   'plate',
#   'dad',
#   'marriage',
#   'dad,',
#   'dad.',
#   'dad!',
#   'dad.”'],
#  'career': ['away,', 'away,', 'would'],
#  'away,': ['idiot.”', 'and'],
#  'idiot.”': ['–'],
#  '–': ['Oh,',
#   'Uh…',
#   'Yeah.',
#   'It’s',
#   'Um…',
#   'Sorry.',
#   'Okay.',
#   'Oh!',
#   'Aw!',
#   '‘I',
#   'And'],
#  'Oh,': ['my', 'fuck.', 'my', 'man.', 'I', 'it’s'],
#  'God.': ['And'],
#  'And': ['I',
#   'he,',
#   'then',
#   'I',
#   'I',
#   'I',
#   'he’s',
#   'I',
#   'he',
#   'I',
#   'he',
#   'that',
#   'I',
#   'I',
#   'he',
#   'I',
#   'I’m',
#   'that',
#   'apparently,',
#   'this',
#   'then',
#   'you’d',
#   'then',
#   'then',
#   'he’s',
#   'you’re',
#   'then',
#   'you’ll',
#   'you’re',
#   'then',
#   'I',
#   'I',
#   'then',
#   'he',
#   'I',
#   'he’s',
#   'he’s',
#   'he',
#   'you’re',
#   'my',
#   'I',
#   'then',
#   'you’re',
#   'you’re',
#   'the',
#   'then',
#   'I',
#   'I',
#   'I’d',
#   'I’m',
#   'you’re',
#   'I',
#   'he',
#   'I',
#   'he’s',
#   'I’m',
#   'this',
#   'you’re',
#   'he',
#   'we',
#   'it’s',
#   'I',
#   'we’re',
#   'I',
#   'he',
#   'he',
#   'I',
#   'he’s'],
#  'high,': ['I'],
#  '“That': ['didn’t'],
#  'happen.”': ['-I'],
#  '“No,': ['no.', 'bro.', 'I', 'but,', 'it’s', 'it’s'],
#  'no.': ['No.'],
#  'No.': ['Nah.”', 'She', 'They'],
#  'Nah.”': ['This'],
#  'This': ['is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'guy,',
#   'guy',
#   'isn’t,',
#   'is',
#   'rocks!”',
#   'is',
#   'is',
#   'shit'],
#  'issue,': ['for'],
#  'sure.': ['He', 'It'],
#  'probably': ['said,'],
#  'said,': ['“See', '“No', 'you', 'guy', 'I’m', 'they’re', '“Uh,', 'he', 'I'],
#  '“See': ['you'],
#  'tomorrow,': ['champ.”'],
#  'champ.”': ['-You'],
#  '-You': ['know,', 'know?'],
#  'probably…': ['So'],
#  'work': ['the', 'to', 'any', 'out,', 'out.', 'out.'],
#  'next': ['day,', 'day,'],
#  'day,': ['and', 'my,', 'you'],
#  'phone': ['call'],
#  'call': ['from', 'the', 'them'],
#  'Lorne': ['Michaels’', 'wants'],
#  'Michaels’': ['office.'],
#  'office.': ['Uh,', 'He'],
#  'Uh,': ['this',
#   'and',
#   'he',
#   'the',
#   'my',
#   'it',
#   'you',
#   'fuck',
#   'and',
#   'it’s',
#   'it',
#   'I',
#   'like,',
#   'and',
#   'so',
#   'thanks',
#   'then',
#   'I',
#   'you',
#   'so',
#   'I’m',
#   'this',
#   'I',
#   'yeah.',
#   'she',
#   'and',
#   'like,',
#   'yeah.',
#   'but',
#   'so',
#   'and',
#   'he',
#   'and'],
#  'alarming': ['because'],
#  'because': ['I’ve', 'I', 'there’s–', 'it’s'],
#  'I’ve': ['been',
#   'had',
#   'never',
#   'done',
#   'tried',
#   'missed?',
#   'lost?',
#   'already',
#   'been',
#   'always',
#   'recently',
#   'been',
#   'been',
#   'heard',
#   'never',
#   'been'],
#  'been': ['there',
#   'like,',
#   'told.',
#   'good',
#   'good,',
#   'in',
#   'making',
#   'prouder.',
#   'dodging',
#   'running',
#   'looking'],
#  'there': ['for', 'to', 'for', 'like,', 'in'],
#  'have': ['yet',
#   'heard',
#   'this',
#   'yearly,',
#   'a',
#   'missed',
#   'sex.',
#   'a',
#   'done',
#   'to',
#   'a',
#   'a–',
#   'a',
#   'my–',
#   'the',
#   'been',
#   'lost',
#   'no',
#   'fuckin’',
#   'pictures.',
#   'a',
#   'your',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'any',
#   'to,'],
#  'yet': ['to'],
#  'hear': ['from', 'is,'],
#  'office': ['until', 'the'],
#  'until': ['today.'],
#  'today.': ['So'],
#  '“Oh,': ['shit.”',
#   'fuck.',
#   'shit.',
#   'so,',
#   'fuck,',
#   'man,',
#   'how’s',
#   'uh,',
#   'it’s',
#   'that–',
#   'we',
#   'I’m'],
#  'shit.”': ['You', 'And'],
#  'You': ['know?',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'know',
#   'know,',
#   'ever,',
#   'know?',
#   'ever',
#   'pieces',
#   'know?',
#   'try',
#   'know,',
#   'know?',
#   'hop',
#   'know,',
#   'know,',
#   'know,',
#   'know?',
#   'know?',
#   'should',
#   'just,',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'know',
#   'know?',
#   'know,',
#   'know.',
#   'ever',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'know?',
#   'know?',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'know?',
#   'know',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'do',
#   'know,',
#   'know?',
#   'know,',
#   'know?',
#   'know?',
#   'know?',
#   'know?',
#   'know,',
#   'know?',
#   'have',
#   'know?',
#   'know?',
#   'know?',
#   'know?',
#   'know?',
#   'know,',
#   'have',
#   'know?',
#   'know',
#   'know?',
#   'know?',
#   'mean,',
#   'know',
#   'know,'],
#  'answered': ['the'],
#  'phone,': ['and'],
#  'they’re': ['like,',
#   'like,',
#   'comfortable,',
#   'on',
#   'about',
#   'just',
#   'trash,'],
#  '“Hey,': ['Louis', 'guys,', 'kid.', 'stop,', 'man,', 'what’s', 'man.'],
#  'left': ['Lorne’s', 'it', 'my'],
#  'Lorne’s': ['office.', 'sitting'],
#  'went': ['in', 'to', 'in'],
#  'talk': ['about', 'to', 'to', 'about'],
#  'about': ['you,',
#   'to',
#   'to',
#   'it,',
#   'to',
#   'how',
#   'the',
#   'this,',
#   'the',
#   'that,',
#   'my',
#   'my',
#   'my',
#   'my'],
#  'you,': ['and',
#   'and',
#   'and,',
#   'but',
#   'you',
#   'Kyle.',
#   'but,',
#   'right?',
#   'but',
#   'like,',
#   'guys.',
#   'the',
#   "Scott?'”"],
#  'now': ['Lorne', 'I', 'I', '♪\n♪', 'he'],
#  'wants': ['to–'],
#  'to–': ['you–'],
#  'you–': ['to'],
#  'now,”': ['and'],
#  'All': ['right.”', 'their', 'right.”', 'right,', 'this', 'right.”'],
#  'right.”': ['You', 'Oh,', 'He'],
#  '’cause': ['I',
#   'people',
#   'I–',
#   'I',
#   'I’m',
#   'now',
#   'you',
#   'it',
#   'all',
#   'I',
#   'apparently',
#   'you',
#   'I',
#   'there’s',
#   'we’re',
#   'he',
#   'I',
#   'I’ve',
#   'it',
#   'I-I',
#   'I',
#   'I’m',
#   'it’s',
#   'I',
#   'everybody',
#   'some',
#   'it',
#   'adults',
#   'I’m',
#   'I’m'],
#  '“Now': ['I’m'],
#  'gettin’': ['fired.”'],
#  'fired.”': ['Like,'],
#  'what': ['I',
#   'to',
#   'you',
#   'I',
#   'I’m',
#   'that',
#   'I',
#   'it',
#   'is',
#   'is',
#   'it',
#   'happened.',
#   'I',
#   'I',
#   'I',
#   'I',
#   'a',
#   'a',
#   'a',
#   'you',
#   'the',
#   'happened',
#   'a',
#   'I',
#   'I',
#   'a',
#   'he'],
#  'thought,': ['so', 'you'],
#  'trying': ['to', 'to', 'to', 'to'],
#  'hype': ['myself'],
#  'myself': ['up.', 'every', 'brown'],
#  'up.': ['It’s', 'That’s', 'Seriously,', 'One'],
#  'like': ['I',
#   'he',
#   'you,',
#   'me,',
#   'me',
#   'being',
#   'four',
#   'that,',
#   'the',
#   'this.',
#   'I’m',
#   'a',
#   'this?”',
#   'that?”',
#   'you’re',
#   'sandpaper.',
#   'that,',
#   'I',
#   'you’re',
#   'three',
#   'a',
#   'a',
#   'that.”',
#   'that.',
#   'being',
#   'a',
#   'is',
#   'that.',
#   'the',
#   'any',
#   'any',
#   'the',
#   'you',
#   'that',
#   'that',
#   'it',
#   'me.',
#   'how',
#   'protect',
#   'I',
#   'to',
#   'white-trash',
#   'where',
#   'our',
#   'I',
#   'an'],
#  '“Fuck': ['them.', 'you.'],
#  'them.': ['They’re'],
#  'They’re': ['the', 'wrong', 'like,', 'talking,', 'just', 'both', 'like,'],
#  'ones': ['who'],
#  'who': ['look', 'just,', 'helped', 'you', 'she', 'this'],
#  'anyway.': ['They'],
#  'They': ['hired',
#   'can',
#   'were',
#   'wait',
#   'were',
#   'just,',
#   'all',
#   'don’t–',
#   'don’t',
#   'just',
#   'decide',
#   'even'],
#  'hired': ['and'],
#  'wrong': ['twice.”'],
#  'twice.”': ['-You'],
#  'Fuckin’…': ['yeah.'],
#  '“You': ['could', 'got', 'need', 'just', 'hate', 'know,', 'know,'],
#  'creep': ['into'],
#  'back': ['and', 'to', 'to', 'of', 'of', 'to', 'to'],
#  'wild': ['out,'],
#  'out,': ['and', 'like,', 'right?', 'right?', 'and', 'but,', 'and', 'like,'],
#  'nobody': ['would'],
#  'notice.': ['-Who'],
#  '-Who': ['gives'],
#  'gives': ['a'],
#  'shit,': ['right?”', 'you'],
#  'right?”': ['Um…', 'You', 'And,', 'I', 'Got', 'No.', 'Uh,'],
#  'Um…': ['So…',
#   'anyway,',
#   'Yeah,',
#   'I',
#   'But,',
#   'So,',
# ...
#   'it',
#   'giggly',
#   'what',
#   'it,',
#   'anything,',
#   'the',
#   'rather',
#   'this',
#   'that',
#   'as'],
#  '“impossible,”': ['but'],
#  'near,': ['for'],
#  'harder': ['things'],
#  'things': ['I’ve', 'you', 'awkward.'],
#  'But,': ['no,', 'you', 'yeah,', 'yeah,', 'uh,', 'uh,'],
#  'no,': ['it', 'yeah,', 'but'],
#  'just–': ['it', 'it', 'it’s,', 'I'],
#  'bummed': ['me'],
#  'hearin’': ['all'],
#  'shit': ['’cause,', 'flies', 'hurts.', 'on,', 'wet!', 'ugly'],
#  'felt': ['bad', 'comfortable'],
#  'bad': ['for', 'happens.', 'turn,'],
#  'those': ['women', 'roasts.”'],
#  'women': ['that'],
#  'jerked': ['off'],
#  'of.': ['It’s'],
#  'sad,': ['you'],
#  'affected': ['them,'],
#  'them,': ['and,', 'and'],
#  'only': ['knew',
#   'the–',
#   'the',
#   'works…',
#   'works',
#   'thing',
#   'have',
#   'thing',
#   'thing',
#   'thing.',
#   'other'],
#  'knew': ['that,', 'what', 'about', 'this,', 'from', 'my'],
#  'when': ['Louis,',
#   'you',
#   'I',
#   'you’re,',
#   'I',
#   'they’re',
#   'they’re',
#   'you’re',
#   'they',
#   'it',
#   'I',
#   'we',
#   'my',
#   'you',
#   'it',
#   'I',
#   'we'],
#  'whipped': ['out'],
#  'dick': ['and', 'in', 'in', 'in', 'gets,', 'and', 'at', 'for', 'summer,'],
#  'started': ['jerkin’', 'writing', 'shitting', 'dating.'],
#  'jerkin’': ['it,'],
#  'it,': ['if',
#   'like,',
#   'and',
#   'and,',
#   'uh,',
#   'but',
#   'like–',
#   '’cause',
#   'I’ve',
#   'and',
#   'right?',
#   'right?',
#   'all',
#   'which',
#   'like,',
#   'like,',
#   'and,'],
#  'lit': ['up'],
#  'blunt,': ['he'],
#  'would’ve': ['been', 'seen'],
#  'fuck,': ['is', 'and', 'joke?'],
#  'weed?': ['Holy'],
#  'Holy': ['shit,'],
#  'animals.': ['I’m'],
#  'telling.': ['You'],
#  'pieces': ['of'],
#  'away': ['your'],
#  'career.”': ['My'],
#  'My': ['friend,', 'bad.', 'career', 'biggest', 'grandpa', 'poor', 'mom'],
#  'friend,': ['uh,', 'uh,', 'right?'],
#  'financially': ['support,'],
#  'support,': ['uh,'],
#  'kid,': ['so,'],
#  'dad.': ['Yeah,', 'I'],
#  'wasn’t': ['exactly', 'your', 'around.”', 'fuckin’', 'gonna', 'expecting'],
#  'exactly': ['ready', 'how', 'what'],
#  'ready': ['for', 'to'],
#  'gave': ['me'],
#  'call.': ['He', '-My'],
#  'excited.': ['He', 'I'],
#  '“Yo,': ['bro.', 'dude,', 'it,', 'guys.', 'I’ve'],
#  'bro.': ['I', 'I', 'Pfft.', 'It’s'],
#  'got': ['great',
#   'a',
#   'it',
#   'my',
#   'pulled',
#   'in',
#   'in',
#   'forced',
#   'this',
#   'to',
#   'to',
#   'called',
#   'out',
#   'a',
#   'us',
#   'the',
#   'rid',
#   'a',
#   'me',
#   'one',
#   'these',
#   'my'],
#  'great': ['news.”', 'General', 'story?”'],
#  'news.”': ['I'],
#  'job?”': ['And'],
#  'kid.”': ['And'],
#  '“Wow,': ['that’s,', 'I’ve'],
#  'that’s,': ['like,'],
#  'exact': ['opposite'],
#  'opposite': ['of'],
#  'job.”': ['I'],
#  'wait': ['to', 'till,'],
#  'kid.': ['I’m', 'You'],
#  'hard': ['at', 'to', 'I', '’cause'],
#  'all.': ['No,', 'Uh,', 'Yeah.', 'I’m', 'Yeah,', 'Cut', 'Twitter’s'],
#  'No,': ['’cause',
#   'no,',
#   'we',
#   'yeah.',
#   'sorry.',
#   'she',
#   'don’t',
#   'she’s',
#   'uh…',
#   'I'],
#  'friends': ['are', 'are', '’cause', 'I’ve', 'in', 'were', 'are', 'would'],
#  'are': ['havin’',
#   'the',
#   'like,',
#   'great.',
#   'like…',
#   'kinda',
#   'some',
#   'the',
#   'pretty',
#   'a',
#   'the',
#   'allowed',
#   'you',
#   'Drake',
#   'jokes.',
#   'they',
#   'like',
#   'just',
#   'saving',
#   'full,',
#   'like,',
#   'like,',
#   'you,',
#   'you?',
#   'you?'],
#  'havin’': ['’em,', 'fun.'],
#  '’em,': ['and'],
#  'their': ['complaints,', 'complaints', 'size.'],
#  'complaints,': ['uh,'],
#  'don’t,': ['uh,', 'either'],
#  'bother': ['me', 'me'],
#  'much.': ['All'],
#  'complaints': ['are'],
#  'same.': ['They’re', 'You'],
#  '“Bro,': ['it', 'I'],
#  'cries!”': ['And'],
#  'man,': ['go', 'what', 'how', 'you'],
#  'room.”': ['Yeah,'],
#  'everything': ['cries.', 'I', 'you'],
#  'cries.': ['You'],
#  'stop,': ['and', 'mister!”', 'please.”'],
#  'leave.': ['I'],
#  'cry': ['all'],
#  'Eventually,': ['my'],
#  'dude,': ['I', '’cause', 'uh,', 'uh,', 'gay', 'uh,'],
#  'gotta': ['go', 'explain', 'tell', 'be'],
#  'work.': ['I', 'Then'],
#  'Fuckin’': ['figure', 'hurts,', 'hate'],
#  'Get': ['offline.”', 'the'],
#  'offline.”': ['So'],
#  'cries,': ['uh,'],
#  'complaint': ['is,'],
#  'shits': ['all'],
#  'time.”': ['And'],
#  'either,': ['because,'],
#  'because,': ['like,', 'uh,', 'like,'],
#  'I.': ['You'],
#  'mind': ['cleaning'],
#  'cleaning': ['it'],
#  'at,': ['like,'],
#  'smaller': ['scale,'],
#  'scale,': ['you'],
#  'Plus,': ['when'],
#  'clean': ['kids,'],
#  'kids,': ['sometimes'],
#  'sometimes': ['you', 'you'],
#  'see': ['spots', 'from', "you.'”", 'across', 'a'],
#  'spots': ['that,'],
#  'might': ['have', 'as', 'have'],
#  'missed': ['on'],
#  'yourself,': ['you', 'and', 'you’re'],
#  'seen': ['my', 'it.', 'a'],
#  'asshole': ['from'],
#  'angle': ['before.”'],
#  'before.”': ['You’re'],
#  'will': ['dab', 'come', 'be', 'say', 'just'],
#  'dab': ['that'],
#  'hop': ['out', 'out'],
#  'shower.”': ['You'],
#  'shower,': ['you’re'],
#  '-“Son': ['of'],
#  'bitch.”': ['I'],
#  'love': ['babysitting…', 'it.', 'livin’', 'you.', 'you,', 'me'],
#  'babysitting…': ['uh,'],
#  'microdose': ['mushrooms,'],
#  'mushrooms,': ['so'],
#  'speak': ['baby.'],
#  'baby.': ['-Uh…'],
#  'talking,': ['you'],
#  'my,': ['uh,'],
#  'nephew': ['was'],
#  '“Bleh,”': ['and'],
#  '“Forensic': ['Files.'],
#  'Files.': ['Got'],
#  'Got': ['it.”', 'that', 'my', 'nowhere'],
#  'it.”': ['So,', 'We’re'],
#  'was…': ['Mushrooms', 'And'],
#  'Mushrooms': ['are', 'are'],
#  'great.': ['Mushrooms', 'Don’t'],
#  'being': ['on', 'a', 'mindful', 'mindful,'],
#  'roller': ['coaster'],
#  'coaster': ['when'],
#  'you’re,': ['like,'],
#  'going': ['up,', 'on?”', 'to', 'on,'],
#  'down.': ['It’s'],
#  'where': ['you’re', 'I', 'you’re', 'it', 'you'],
#  'sick!': ['This'],
#  'awesome!': ['I'],
#  'doin’': ['this!'],
#  'this!': ['Oh,'],
#  'God!”': ['for'],
#  'four': ['hours.', 'were,'],
#  'hours.': ['Something'],
#  'Something': ['weird,'],
#  'weird,': ['uh,'],
#  'babysitting,': ['uh,'],
#  'day.': ['Uh,'],
#  'son': ['i-is', 'could', 'or'],
#  'i-is': ['still'],
#  'teething,': ['right?', 'so'],
#  'And,': ['uh,', 'uh,', 'uh,'],
#  'were': ['watchin’',
#   'twisted',
#   'just',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'in,',
#   'like,',
#   'together.',
#   'from',
#   'telling'],
#  'watchin’': ['Forensic'],
#  'Forensic': ['Files,'],
#  'Files,': ['and'],
#  'sittin’': ['there,', 'there,'],
#  'h-he’s': ['teething,'],
#  'grabbed': ['my'],
#  'hand': ['and'],
#  'started,': ['like,', 'like,'],
#  'sucking': ['my'],
#  'fingers,': ['but,'],
#  'good.': ['-Like…', 'Better'],
#  '-Like…': ['Like,'],
#  'definitely': ['left'],
#  'second.': ['I'],
#  '“No!': ['Wow,', 'I', 'You’re'],
#  'Wow,': ['but'],
#  'no!”': ['I'],
#  'joke': ['splits', 'or', 'I', 'the'],
#  'splits': ['the'],
#  'room.': ['-Uh…'],
#  'aware.': ['It’s'],
#  'not': ['the',
#   'very',
#   'many',
#   'the',
#   'this',
#   'fuckin’',
#   'a',
#   'allowed',
#   'being',
#   'mine.',
#   'true.',
#   'make',
#   'do',
#   'true.',
#   'why.',
#   'a',
#   'supposed',
#   'how',
#   'a',
#   'a',
#   'telling'],
#  'time': ['I’ve', 'you', 'something', 'I', 'we', 'I’ll'],
#  'done': ['this.', 'it'],
#  'this.': ['Uh…', 'The,', 'Congrats', 'Uh…', 'She’s'],
#  'weird': ['to', 'if', 'friend', 'friend,', '’cause', '’cause', 'meaning'],
#  'jokes': ['like', 'about', '♪'],
#  'joke,': ['you', 'right,', 'like,'],
#  'comedy': ['club.'],
#  'club.': ['You'],
#  'town': ['hall'],
#  'hall': ['meeting,'],
#  'meeting,': ['and'],
#  'I,': ['like,', 'um…', 'um…', 'like,'],
#  'grab': ['the', 'her'],
#  'mic,': ['and'],
#  'guys,': ['here', 'uh,'],
#  'here': ['are', 'Like,'],
#  'some': ['ideas',
#   'new',
#   'jokes,',
#   'research.”',
#   'research',
#   'repercussions,',
#   '9/11',
#   'people',
#   'stories'],
#  'ideas': ['I'],
#  'have.”': ['“All'],
#  'buttons.”': ['Um…'],
#  'girls': ['should', 'should', 'come.', 'can’t'],
#  'should': ['tell', 'tell', 'just', 'just', 'apologize', 'say'],
#  'guys': ['how', 'go', 'have,', 'for'],
#  'them': ['come.', 'is', 'come.', 'the', 'in'],
#  'come.': ['Uh…', 'Not', 'You'],
#  'sex.': ['Before,'],
#  'Before,': ['like,'],
#  'debriefing,': ['you'],
#  'apparently': ['every'],
#  'girl': ['is', 'ever,', 'I', 'will', 'that', 'alive?'],
#  'different': ['is,'],
#  'telling': ['myself.', 'me', 'you', 'people'],
#  'myself.': ['Everyone'],
#  'Everyone': ['is'],
#  'different,': ['and'],
#  'dead': ['inside.'],
#  'inside.': ['-Um…'],
#  'think–': ['I’m'],
#  'broken.”': ['-Uh…'],
#  'yeah,': ['yeah.',
#   'girls',
#   'apparently,',
#   'you',
#   'here’s',
#   'you',
#   'I',
#   'it’s'],
#  'Sorry.': ['I', 'I'],
#  'Sometimes,': ['you'],
#  'giggly': ['things.'],
#  'things.': ['Um,'],
#  'comfortable,': ['you'],
#  'hurt': ['the'],
#  'guy’s': ['feelings,', 'like,'],
#  'feelings,': ['but'],
#  'won’t.': ['Uh,'],
#  'doesn’t.': ['You'],
#  'be–': ['we'],
#  'mid-,': ['you'],
#  'hate': ['this,”', 'that', 'pussy', 'this.”', 'America!”', 'America.'],
#  'this,”': ['and'],
#  'we’ll': ['be', 'cut', 'do', 'get', 'check'],
#  'how’s': ['this?'],
#  'this?': ['Good?', 'Is', 'Did'],
#  'Good?': ['Okay,'],
#  'Okay,': ['forgotten.”'],
#  'forgotten.”': ['You'],
#  'Didn’t': ['even', 'even', 'work'],
#  'happen.': ['You'],
#  'guy,': ['you', 'you', 'you', 'okay?', 'uh,', 'that', 'that', 'Dan'],
#  'guess': ['guy', 'girls', 'I’ll', 'we’ll', 'the'],
#  'stuff': ['is', 'is', 'I', 'on', 'like'],
#  'self-explanatory,': ['right?', 'but'],
#  'yank': ['it,'],
#  'flies': ['out,'],
#  'easy.': ['Like,'],
#  '-Aw.': ['But'],
#  'But': ['yeah,',
#   'I',
#   'it–',
#   'there’s',
#   'I-I',
#   'when',
#   'yeah.',
#   'they',
#   'I’m'],
#  'apparently,': ['you', 'the'],
#  'sweating': ['and'],
#  'breath,': ['I’m'],
#  'wrong.': ['But,', 'It'],
#  'from,': ['like,'],
#  'porn': ['because'],
#  'grew': ['up', 'up'],
#  'sister,': ['right?', 'right?'],
#  'talk,': ['you'],
#  'dinner': ['where'],
#  'comfortable': ['to', 'with'],
#  'guys.': ['If', 'Have', 'Thanks'],
#  'If': ['I', 'you’re', 'you', 'you', 'I', 'I', 'I', 'I’mma'],
#  'brother,': ['uh…”'],
#  'uh…”': ['You'],
#  'knew,': ['uh,'],
#  'porn,': ['which'],
#  'which': ['is,', 'we', 'is', 'I', 'every–', 'I', 'is', 'way,'],
#  'movement': ['and,'],
#  'screaming': ['and,'],
#  'take': ['it', 'a'],
#  'couple': ['push-ups,'],
#  'push-ups,': ['you'],
#  'right…': ['Um,'],
#  'sorry.': ['You',
#   'Like,',
#   '–',
#   'I',
#   'I’m',
#   'I',
#   'I',
#   'Uh…',
#   'Please',
#   'Was',
#   'Should'],
#  'really–': ['I'],
#  'luckily,': ['uh,'],
#  'one,': ['uh,'],
#  'lady': ['told', 'suit'],
#  'me.': ['Apparently,', 'You', 'They–', 'Uh…'],
#  'Apparently,': ['there’s'],
#  'there’s': ['just,',
#   'this',
#   'just,',
#   'a–',
#   'the',
#   'no…',
#   'always',
#   'this–',
#   'no',
#   'a',
#   'the',
#   'certain',
#   'like'],
#  'little…': ['uh,'],
#  'little': ['thing',
#   'circle',
#   'thing',
#   'dicks.',
#   'giggle',
#   'joke,',
#   'unfair.',
#   'hands.',
#   'hands.',
#   'bit',
#   'bit.',
#   'bit'],
#  'thing': ['in',
#   'that’s',
#   'that',
#   'very,',
#   'I-I-I-I',
#   'I',
#   'I’m',
#   'I',
#   'about'],
#  'vagina.': ['It’s,'],
#  'It’s,': ['like,', 'well–'],
#  'circle': ['thing.'],
#  'thing.': ['I-It', 'The', 'Roast', 'Hey,', 'If', 'It', 'So'],
#  'I-It': ['kinda…'],
#  'kinda…': ['You'],
#  'boxing?': ['It'],
#  'The,': ['like,'],
#  'speed': ['bag'],
#  'bag': ['thing.'],
#  'The': ['thing', 'sleepovers,', 'only', 'guy'],
#  'slow': ['or'],
#  'quite': ['fast', 'the'],
#  'fast': ['on.'],
#  'on.': ['And', 'He’s'],
#  'vagina': ['is,'],
#  'tap': ['that'],
#  'very,': ['very', 'uh,', 'very'],
#  'lightly…': ['uh,'],
#  'or–': ['or'],
#  'floor': ['it,', 'it,', 'to'],
#  'apparently.': ['Those'],
#  'Those': ['are', 'are'],
#  'two': ['options.'],
#  'options.': ['Yeah.'],
#  'Don’t': ['even', 'worry,'],
#  'change': ['your'],
#  'outfit.': ['Uh…'],
#  'Like': ['I', 'I', 'Anna'],
#  'pulled': ['my', 'over', 'over,'],
#  'pants': ['down'],
#  'down': ['and', 'there,', 'there.', '♪\n♪'],
#  'punching': ['my'],
#  'dick,': ['I', 'seriously.'],
#  'wouldn’t': ['be', 'have'],
#  '“Aw,': ['fuck!', 'please.', 'sick.', 'fuck.', 'that’s–', 'well,'],
#  'fuck!': ['I'],
#  'hope': ['she', 'so.'],
#  'she': ['figures',
#   'wasn’t',
#   'had',
#   'just',
#   'say',
#   'said',
#   'is.”',
#   'talked',
#   'knows',
#   'tell',
#   'do',
#   'wan-wanted',
#   'figured',
#   'comes.'],
#  'figures': ['it'],
#  '-Ow,': ['ow,'],
#  'ow,': ['ow,', 'ow,', 'ow,', 'ow!'],
#  'ow!': ['This'],
#  'war.”': ['I'],
#  '“Who': ['sent'],
#  'sent': ['you?'],
#  'you?': ['What', 'Am', 'I', 'It’s'],
#  'Is': ['this…', 'this', 'it,', 'that', 'this', 'this'],
#  'this…': ['Is'],
#  'an': ['assassination',
#   'Indian',
#   'Indian',
#   'example.',
#   'apartment…',
#   'eye',
#   'eye',
#   'eye',
#   'eye',
#   'eye',
#   'expression.',
#   'expression.',
#   'eye',
#   'example.',
#   'oddly'],
#  'assassination': ['attempt?”'],
#  'attempt?”': ['Like,'],
#  'here’s': ['something,', 'something'],
#  'something,': ['uh,'],
#  'no': ['guy',
#   'guy',
#   'guy',
#   'rule',
#   'fuckin’',
#   'reason,',
#   'idea',
#   'smoke',
#   'problem,'],
#  'likes,': ['but', 'uh,'],
#  'we’re,': ['like,', 'like,'],
#  'afraid,': ['uh,'],
#  'tell,': ['uh,', 'because,'],
#  'girl,': ['you', 'you', 'right?', 'and', 'right?'],
#  'close': ['to…'],
#  'to…': ['b-banging…'],
#  'b-banging…': ['There’s'],
#  'many': ['words,', 'fuckin’', 'of', 'bridges'],
#  'words,': ['uh,'],
#  't-to': ['say'],
#  '“banging”': ['is,'],
#  'most': ['appropriate…', 'honest', 'of'],
#  'appropriate…': ['for…'],
#  'for…': ['And'],
#  'Nickelodeon.': ['-Yeah.'],
#  '-Yeah.': ['You'],
#  'wore': ['a'],
#  'suit,': ['you'],
#  'usually,': ['I'],
#  'don’t.': ['I', 'Fuckin’'],
#  'always': ['just',
#   'one',
#   'hanging',
#   'lose,',
#   'wanted',
#   'wanted',
#   'on',
#   'used',
#   'played',
#   'knew',
#   'said'],
#  'usually': ['dress', 'they'],
#  'dress': ['like'],
#  'slimed.': ['-Uh,'],
#  '-Uh,': ['but…', 'and,'],
#  'but…': ['But', 'Just', 'yeah.'],
#  'found': ['a'],
#  'suit': ['at'],
#  'Banana': ['Republic,'],
#  'Republic,': ['and'],
#  'crushing': ['it'],
#  'right': ['now.',
#   'now,',
#   'in',
#   'out.',
#   'out.',
#   'before',
#   'now,',
#   'after,',
#   'in'],
#  'now.': ['I', 'What'],
#  'divorced': ['wife'],
#  'wife': ['who'],
#  'together.': ['“Don’t', 'I'],
#  '“Don’t': ['come'],
#  'come': ['back.', 'up', 'out', 'up,', 'to', 'over', 'over', 'in?'],
#  'back.': ['I', 'I', 'Can'],
#  'repertoire': ['now.”'],
#  'now.”': ['Um…'],
#  'something': ['that–', 'like', 'bad', 'like', 'had'],
#  'that–': ['that', 'that,', 'Well,', 'You'],
#  'no–': ['no', 'no'],
#  'when,': ['like,'],
#  'girl’s': ['on'],
#  'top,': ['right?', 'and', 'and'],
#  'Before': ['they,'],
#  'they,': ['like,'],
#  'shove': ['the', 'the'],
#  'them?': ['Again,'],
#  'Again,': ['I', 'these', 'I'],
#  'ways,': ['and'],
#  '“shove': ['the'],
#  'them”': ['won'],
#  'won': ['by,', 'the', 'Billboard’s'],
#  'by,': ['like,', 'like,'],
#  'landslide.': ['-I-It…'],
#  '-I-It…': ['So'],
#  'imagine': ['how', 'if', 'if', 'if', 'if', 'if'],
#  'horrible': ['the', 'story.'],
#  '-Suddenly': ['it’s'],
#  'better.': ['Um…'],
#  'slam': ['it'],
#  'there?': ['-Uh…'],
#  'See?': ['Yeah.'],
#  'sayin’.': ['So'],
#  'ya?': ['Uh…'],
#  'Some–': ['Some'],
#  'Some': ['girls,'],
#  'girls,': ['most,'],
#  'most,': ['uh,'],
#  'start': ['sliding,', 'fucking'],
#  'sliding,': ['uh,'],
#  'o-on': ['top'],
#  'top': ['of'],
#  'dicks': ['before'],
#  'before': ['they', 'you', 'I’m', 'it', 'I', 'I'],
#  'there.': ['They’re', 'Please.', 'I', 'Um…'],
#  '“Yeah.': ['Yeah,', 'Luckily,'],
#  'this?”': ['No,', 'You’re', 'And', 'Doctors'],
#  'hurts,': ['a', 'you', 'a'],
#  'lot.': ['Stop', 'You', 'Uh,'],
#  'Stop': ['doing'],
#  'please.': ['Please.', 'He’s'],
#  'Please.': ['Just', 'It'],
#  'hurts': ['so'],
#  'bad.': ['It', 'Feels', 'It’s'],
#  'shave': ['or'],
#  'either': ['way,'],
#  'way,': ['you’re', 'right?', 'you'],
#  'prickly': ['down'],
#  'start,': ['like,'],
#  'rubbing': ['that'],
#  'against': ['our', 'gayness.'],
#  'our': ['bare', 'friends,', 'homework,', 'life!”'],
#  'bare': ['little'],
#  'dicks.': ['That'],
#  'That': ['shit', 'is,', 'shit', 'was', 'would', 'is'],
#  'hurts.': ['You’re'],
#  '“Ooh,': ['you'],
#  'that?”': ['We’re'],
#  'We’re': ['like,',
#   'havin’',
#   'keeping',
#   'garbage',
#   'fuckin’',
#   'getting',
#   'sharing',
#   'sharing'],
#  '“No.': ['Have', 'That'],
#  'Have': ['you', 'a', 'a'],
#  'gotten': ['an'],
#  'Indian': ['burn?', 'burn?”'],
#  'burn?': ['‘Cause'],
#  'feels': ['like.', 'very'],
#  'like.': ['Feels'],
#  'Feels': ['like', 'like'],
#  'mom’s': ['weird', 'house'],
#  'friend': ['that', 'that'],
#  '-when': ['she'],
#  'around.”': ['Yeah,', 'Your'],
#  'everybody': ['remembers',
#   'knows.”',
#   'else,',
#   'on',
#   'sees',
#   'was',
#   'what',
#   'he',
#   'fat.'],
#  'remembers': ['that'],
#  'Everybody’d': ['go'],
#  'upstairs,': ['and'],
#  'he’d': ['be', 'be'],
#  'burn?”': ['And'],
#  'you’d': ['be', 'be', 'be'],
#  '“No,”': ['and'],
#  'first,': ['you’d', 'obviously,'],
#  ...}

# %% [markdown]
# ## Create a Text Generator
# We're going to create a function that generates sentences. It will take two things as inputs:
#
# - The dictionary you just created
# - The number of words you want generated

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(pete_dict)
# Out:
# 'Wasn’t–” And you’re like, speed bag thing. The sleepovers, you know, stuff like I had.'
